# %% [markdown]
# ## Import Data ##

# %%
import pandas as pd

data = pd.read_csv("Icecream.csv")
data = data.replace("No", 0)
data = data.replace("Yes", 1)

df = data

df
# Out:
# /var/folders/wd/yv2kv5sn1kn30nq5ppyppw6r0000gn/T/ipykernel_2448/799481815.py:5: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data = data.replace("Yes", 1)
#     Temperature (F)  Ice-cream Price ($)  Number of Tourists (thousands)  \
# 0              80.6                 1.00                            89.5
# 1              75.2                 1.00                            86.4
# 2              86.0                 2.00                            99.2
# 3              75.2                 2.00                            72.4
# 4              60.8                 2.00                            71.2
# 5              68.0                 2.00                            71.0
# 6              71.6                 1.25                            78.0
# 7              66.2                 1.50                            74.3
# 8              60.8                 1.50                            69.4
# 9              78.8                 1.50                            82.5
# 10             78.8                 1.50                            75.2
# 11             62.6                 1.00                            70.3
# 12             75.2                 1.00                            88.6
# 13             75.2                 1.00                            74.5
# 14             69.8                 0.75                            71.1
# 15             64.4                 0.75                            52.1
# 16             71.6                 0.75                            88.4
# 17             86.0                 0.75                            95.2
# 18             78.8                 2.00                            81.9
# 19             77.0                 2.00                            87.9
#
#     Ice Cream Sales ($,thousands)  Did it rain on that day?
# 0                              90                         0
# 1                              85                         0
# 2                             107                         0
# 3                              71                         1
# 4                              65                         1
# 5                              69                         1
# 6                              67                         1
# 7                              70                         1
# 8                              65                         1
# 9                              81                         1
# 10                             73                         1
# 11                             64                         1
# 12                             89                         1
# 13                             79                         1
# 14                             66                         1
# 15                             53                         1
# 16                             75                         1
# 17                             99                         0
# 18                             81                         0
# 19                             88                         0

# %%
X = df.drop(columns=["Did it rain on that day?"])
y = df["Did it rain on that day?"]

# %% [markdown]
# ## Clean Up Data ##

# %%
#df = data.loc[:, ~data.map(lambda x: isinstance(x, str)).any(axis=0)] #axis=0 deletes any columns with string values
                                                                      #(string values can be encoded as numbers however, 
                                                                      #and decoded to be readable, think Natural Language Processing)

#data = data.drop("", axis=1) #if predicting a string value that use this instead of above command

#drop rows with missing value from prediction column
#df.dropna(subset=[""], inplace=True)

#drop duplicate rows
df.drop_duplicates(inplace=True)

# %% [markdown]
# ## Data Analysis ##

# %%
df.corr()
# Out:
#                                 Temperature (F)  Ice-cream Price ($)  \
# Temperature (F)                        1.000000             0.039864
# Ice-cream Price ($)                    0.039864             1.000000
# Number of Tourists (thousands)         0.779084             0.045092
# Ice Cream Sales ($,thousands)          0.862798             0.094629
# Did it rain on that day?              -0.660333            -0.129634
#
#                                 Number of Tourists (thousands)  \
# Temperature (F)                                       0.779084
# Ice-cream Price ($)                                   0.045092
# Number of Tourists (thousands)                        1.000000
# Ice Cream Sales ($,thousands)                         0.933405
# Did it rain on that day?                             -0.675883
#
#                                 Ice Cream Sales ($,thousands)  \
# Temperature (F)                                      0.862798
# Ice-cream Price ($)                                  0.094629
# Number of Tourists (thousands)                       0.933405
# Ice Cream Sales ($,thousands)                        1.000000
# Did it rain on that day?                            -0.750530
#
#                                 Did it rain on that day?
# Temperature (F)                                -0.660333
# Ice-cream Price ($)                            -0.129634
# Number of Tourists (thousands)                 -0.675883
# Ice Cream Sales ($,thousands)                  -0.750530
# Did it rain on that day?                        1.000000

# %%
from scipy.stats import *

# %%
import matplotlib.pyplot as plt
import seaborn as sn

# %% [markdown]
# ## Data Optimization ##

# %%
import numpy as np

a = 0
z = 1
d = df.iloc[0:19, a:z] #[Rows, Columns]
f = np.array([[12, 3, 4], [5, 1, 2]]) #Matrix
vec_df = d*2 #Numpy operations to weight data

#re-inserting weighted data back into the dataset
v = pd.DataFrame(vec_df, columns = df.columns[a:(z+1)].tolist())
df.update(v)

df
# Out:
#     Temperature (F)  Ice-cream Price ($)  Number of Tourists (thousands)  \
# 0             161.2                 1.00                            89.5
# 1             150.4                 1.00                            86.4
# 2             172.0                 2.00                            99.2
# 3             150.4                 2.00                            72.4
# 4             121.6                 2.00                            71.2
# 5             136.0                 2.00                            71.0
# 6             143.2                 1.25                            78.0
# 7             132.4                 1.50                            74.3
# 8             121.6                 1.50                            69.4
# 9             157.6                 1.50                            82.5
# 10            157.6                 1.50                            75.2
# 11            125.2                 1.00                            70.3
# 12            150.4                 1.00                            88.6
# 13            150.4                 1.00                            74.5
# 14            139.6                 0.75                            71.1
# 15            128.8                 0.75                            52.1
# 16            143.2                 0.75                            88.4
# 17            172.0                 0.75                            95.2
# 18            157.6                 2.00                            81.9
# 19             77.0                 2.00                            87.9
#
#     Ice Cream Sales ($,thousands)  Did it rain on that day?
# 0                              90                         0
# 1                              85                         0
# 2                             107                         0
# 3                              71                         1
# 4                              65                         1
# 5                              69                         1
# 6                              67                         1
# 7                              70                         1
# 8                              65                         1
# 9                              81                         1
# 10                             73                         1
# 11                             64                         1
# 12                             89                         1
# 13                             79                         1
# 14                             66                         1
# 15                             53                         1
# 16                             75                         1
# 17                             99                         0
# 18                             81                         0
# 19                             88                         0

# %% [markdown]
# ## Optimization ##

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import mean_squared_error
from bayes_opt import BayesianOptimization
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import train_test_split

# Define the function to optimize using cross-validation
def dtree_cv(max_depth, min_samples_split, min_samples_leaf):
    # Define the model with the parameters to be optimized
    estimator = RandomForestRegressor(
        max_depth=int(max_depth),
        min_samples_split=int(min_samples_split),
        min_samples_leaf=int(min_samples_leaf),
        random_state=2
    )
    cval = cross_val_score(estimator, X_train, y_train, scoring='neg_mean_squared_error', cv=5)
    return cval.mean() # The optimizer tries to maximize the function, so we negate the score to minimize it

# Define the parameter bounds
param_bounds = {
    'max_depth': (1, 20),
    'min_samples_split': (2, 20),
    'min_samples_leaf': (1, 20)
}

optimizer = BayesianOptimization(
    f=dtree_cv,
    pbounds=param_bounds,
    random_state=1,
)

optimizer.maximize(n_iter=100, init_points=6) # Bayesian optimization
best_params_bayes = optimizer.max['params']
best_params_bayes['max_depth'] = int(best_params_bayes['max_depth'])
best_params_bayes['min_samples_split'] = int(best_params_bayes['min_samples_split'])
best_params_bayes['min_samples_leaf'] = int(best_params_bayes['min_samples_leaf'])
best_score_bayes = optimizer.max['target']

print(f"Best Parameters (Bayesian Optimization): {best_params_bayes}")
print(f"Best Score (Bayesian Optimization): {best_score_bayes}")
# Out:
# |   iter    |  target   | max_depth | min_sa... | min_sa... |
# -------------------------------------------------------------
# | 1         | -0.2596   | 8.923     | 14.69     | 2.002     |
# | 2         | -0.1999   | 6.744     | 3.788     | 3.662     |
# | 3         | -0.2596   | 4.539     | 7.566     | 9.142     |
# | 4         | -0.2596   | 11.24     | 8.965     | 14.33     |
# | 5         | -0.2596   | 4.885     | 17.68     | 2.493     |
# | 6         | -0.2596   | 13.74     | 8.929     | 12.06     |
# | 7         | -0.2726   | 6.915     | 1.34      | 2.172     |
# | 8         | -0.2596   | 11.11     | 15.96     | 5.148     |
# | 9         | -0.2596   | 12.32     | 5.959     | 15.44     |
# | 10        | -0.2596   | 5.323     | 3.956     | 19.05     |
# | 11        | -0.2596   | 14.8      | 14.84     | 5.504     |
# | 12        | -0.2596   | 9.935     | 9.046     | 10.49     |
# | 13        | -0.2596   | 19.15     | 13.62     | 10.47     |
# | 14        | -0.2596   | 10.29     | 16.98     | 19.62     |
# | 15        | -0.2596   | 7.127     | 15.51     | 17.43     |
# | 16        | -0.2596   | 17.24     | 14.67     | 18.42     |
# | 17        | -0.2596   | 13.87     | 11.41     | 8.898     |
# | 18        | -0.2058   | 3.674     | 3.648     | 7.703     |
# | 19        | -0.2596   | 6.206     | 15.52     | 3.204     |
# | 20        | -0.2596   | 18.85     | 19.05     | 7.024     |
# | 21        | -0.1999   | 12.37     | 3.141     | 4.102     |
# | 22        | -0.2596   | 12.66     | 11.59     | 13.76     |
# | 23        | -0.2596   | 1.319     | 5.909     | 16.41     |
# | 24        | -0.2596   | 6.934     | 11.38     | 16.88     |
# | 25        | -0.2596   | 9.815     | 3.581     | 12.21     |
# | 26        | -0.2596   | 18.32     | 12.83     | 19.45     |
# | 27        | -0.2596   | 16.28     | 7.041     | 12.92     |
# | 28        | -0.2596   | 5.371     | 2.231     | 14.67     |
# | 29        | -0.2596   | 17.3      | 17.21     | 17.88     |
# | 30        | -0.2484   | 12.37     | 3.187     | 9.365     |
# | 31        | -0.2596   | 16.94     | 8.952     | 7.33      |
# | 32        | -0.1999   | 12.67     | 3.153     | 4.047     |
# | 33        | -0.2195   | 6.612     | 4.495     | 5.186     |
# | 34        | -0.2578   | 7.853     | 5.013     | 2.875     |
# | 35        | -0.1999   | 5.886     | 3.138     | 4.19      |
# | 36        | -0.2195   | 5.556     | 4.16      | 3.741     |
# | 37        | -0.1999   | 7.106     | 3.406     | 4.645     |
# | 38        | -0.216    | 4.617     | 2.643     | 6.273     |
# | 39        | -0.2356   | 12.68     | 1.365     | 4.536     |
# | 40        | -0.2195   | 12.42     | 4.086     | 5.318     |
# | 41        | -0.2195   | 12.11     | 4.126     | 2.713     |
# | 42        | -0.1999   | 2.224     | 3.381     | 6.821     |
# | 43        | -0.227    | 1.751     | 2.23      | 8.617     |
# | 44        | -0.2578   | 1.445     | 5.095     | 6.846     |
# | 45        | -0.2195   | 2.848     | 1.892     | 6.632     |
# | 46        | -0.1999   | 3.512     | 3.499     | 5.681     |
# | 47        | -0.2136   | 1.676     | 2.757     | 4.484     |
# | 48        | -0.1999   | 15.03     | 3.732     | 3.119     |
# | 49        | -0.2108   | 15.57     | 2.25      | 2.211     |
# | 50        | -0.1999   | 17.29     | 3.806     | 3.492     |
# | 51        | -0.2195   | 16.84     | 4.727     | 2.029     |
# | 52        | -0.214    | 16.18     | 2.903     | 5.303     |
# | 53        | -0.2108   | 18.83     | 2.006     | 3.921     |
# | 54        | -0.2195   | 19.3      | 4.789     | 4.821     |
# | 55        | -0.2578   | 15.64     | 5.122     | 4.535     |
# | 56        | -0.1999   | 19.11     | 3.238     | 2.469     |
# | 57        | -0.2108   | 16.51     | 2.278     | 3.657     |
# | 58        | -0.2171   | 19.39     | 2.17      | 7.093     |
# | 59        | -0.2578   | 19.87     | 5.061     | 2.475     |
# | 60        | -0.2108   | 18.33     | 2.213     | 2.116     |
# | 61        | -0.1999   | 14.15     | 3.343     | 2.169     |
# | 62        | -0.2271   | 17.04     | 1.363     | 8.399     |
# | 63        | -0.2468   | 19.87     | 4.193     | 9.23      |
# | 64        | -0.1999   | 18.8      | 3.261     | 5.206     |
# | 65        | -0.2596   | 1.089     | 19.93     | 11.94     |
# | 66        | -0.2596   | 19.99     | 1.567     | 19.48     |
# | 67        | -0.2596   | 1.198     | 18.93     | 19.87     |
# | 68        | -0.2596   | 11.43     | 19.91     | 11.58     |
# | 69        | -0.214    | 9.113     | 2.356     | 5.801     |
# | 70        | -0.2271   | 8.12      | 1.009     | 8.151     |
# | 71        | -0.2152   | 1.012     | 1.097     | 2.461     |
# | 72        | -0.2596   | 1.007     | 14.27     | 7.443     |
# | 73        | -0.2002   | 1.778     | 3.749     | 2.261     |
# | 74        | -0.2596   | 1.544     | 6.419     | 2.153     |
# | 75        | -0.2107   | 2.421     | 2.559     | 2.187     |
# | 76        | -0.2596   | 13.14     | 1.467     | 19.8      |
# | 77        | -0.2596   | 19.41     | 14.11     | 2.304     |
# | 78        | -0.2596   | 1.273     | 11.78     | 19.69     |
# | 79        | -0.1999   | 18.38     | 3.407     | 3.704     |
# | 80        | -0.2596   | 17.97     | 1.038     | 12.88     |
# | 81        | -0.2596   | 15.01     | 19.87     | 2.396     |
# | 82        | -0.2194   | 17.76     | 1.488     | 6.011     |
# | 83        | -0.2596   | 19.07     | 19.93     | 13.47     |
# | 84        | -0.2596   | 19.94     | 7.141     | 18.04     |
# | 85        | -0.2726   | 19.83     | 1.1       | 2.031     |
# | 86        | -0.1999   | 17.17     | 3.254     | 2.174     |
# | 87        | -0.2726   | 12.15     | 1.993     | 2.038     |
# | 88        | -0.1999   | 18.14     | 3.581     | 6.514     |
# | 89        | -0.2195   | 13.8      | 4.948     | 2.142     |
# | 90        | -0.2002   | 1.236     | 3.012     | 2.012     |
# | 91        | -0.2596   | 5.306     | 19.92     | 8.234     |
# | 92        | -0.2596   | 1.271     | 12.89     | 12.94     |
# | 93        | -0.2596   | 12.98     | 10.45     | 19.97     |
# | 94        | -0.2058   | 8.287     | 3.762     | 7.75      |
# | 95        | -0.2195   | 6.155     | 4.151     | 8.893     |
# | 96        | -0.2195   | 9.617     | 4.479     | 5.612     |
# | 97        | -0.2596   | 1.725     | 1.24      | 19.93     |
# | 98        | -0.2596   | 1.029     | 19.84     | 3.033     |
# | 99        | -0.2171   | 7.205     | 2.93      | 7.289     |
# | 100       | -0.2578   | 9.111     | 5.419     | 8.088     |
# | 101       | -0.2171   | 9.975     | 2.499     | 7.636     |
# | 102       | -0.2586   | 4.484     | 2.072     | 10.25     |
# | 103       | -0.2596   | 19.88     | 19.89     | 19.96     |
# | 104       | -0.2596   | 5.129     | 19.89     | 15.26     |
# | 105       | -0.2195   | 19.63     | 4.297     | 6.606     |
# | 106       | -0.2596   | 1.558     | 12.66     | 2.351     |
# =============================================================
# Best Parameters (Bayesian Optimization): {'max_depth': 6, 'min_samples_leaf': 3, 'min_samples_split': 3}
# Best Score (Bayesian Optimization): -0.1999455807940256

# %% [markdown]
# ## Training and Testing Data ##

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 29)


model = RandomForestClassifier(max_depth = 6, min_samples_leaf = 3, min_samples_split = 3)
model.fit(X_train.values, y_train)

#predictions = model.predict([[, , ,]])
predictions1 = model.predict(X_test)
score = accuracy_score(y_test, predictions1)
#print(predictions, f"\nAccuracy: {score}")
print(f"Accuracy: {score}")
# Out:
# Accuracy: 1.0
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/base.py:486: UserWarning: X has feature names, but RandomForestClassifier was fitted without feature names
#   warnings.warn(

# %% [markdown]
# ## Predicted vs Actual ##

# %%
y_predicted = model.predict(X_test)
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/base.py:486: UserWarning: X has feature names, but RandomForestClassifier was fitted without feature names
#   warnings.warn(

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_predicted)
cm
# Out:
# array([[1, 0],
#        [0, 5]])

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sn

plt.figure(figsize=(10, 7))
sn.heatmap(cm, annot=True)
plt.xlabel("Predicted")
plt.ylabel("Actual")
# Out:
# Text(95.72222222222221, 0.5, 'Actual')
