# %% [markdown]
# ## Import Data ##

# %%
import pandas as pd
import numpy as np

data = pd.read_csv("TurkMusic.csv")
df = data

df
# Out:
#      Class  _Fluctuation_Mean  _MFCC_Mean_2  _MFCC_Mean_4  _MFCC_Mean_7  \
# 0    relax              9.136         0.363         0.078        -0.151
# 1    relax              6.680         0.516         0.397        -0.403
# 2    relax             10.578         0.903         0.329        -0.246
# 3    relax             10.442         1.552         0.351         0.047
# 4    relax              9.769         0.228         0.096         0.104
# ..     ...                ...           ...           ...           ...
# 395  angry              5.265         0.065         0.046         0.198
# 396  angry              5.042        -0.148        -0.011         0.065
# 397  angry              4.724         0.566        -0.113         0.278
# 398  angry              4.470        -0.210         0.089         0.173
# 399  angry              5.343        -0.014        -0.021         0.310
#
#      _Roughness_Mean  _Roughness_Slope  _Zero-crossingrate_Mean  \
# 0             51.542             0.325                  403.129
# 1            336.839             0.366                  204.886
# 2             39.864             0.224                  685.474
# 3            353.744             0.215                  579.859
# 4             46.884            -0.118                  430.536
# ..               ...               ...                      ...
# 395          547.713             0.060                  493.908
# 396         1121.910             0.032                  975.308
# 397          889.926            -0.010                  916.985
# 398          408.726             0.174                  670.306
# 399          258.400            -0.000                  396.386
#
#      _AttackTime_Mean  _Eventdensity_Mean  _Pulseclarity_Mean  \
# 0               0.028               1.336               0.082
# 1               0.015               1.336               0.051
# 2               0.033               1.336               0.299
# 3               0.029               2.105               0.121
# 4               0.040               1.370               0.208
# ..                ...                 ...                 ...
# 395             0.025               4.076               0.514
# 396             0.014               3.687               0.589
# 397             0.017               2.940               0.077
# 398             0.025               2.539               0.317
# 399             0.017               4.744               0.258
#
#      _Chromagram_Mean_7  _HarmonicChangeDetectionFunction_Mean  \
# 0                 0.024                                  0.316
# 1                 0.120                                  0.285
# 2                 0.563                                  0.413
# 3                 0.276                                  0.422
# 4                 0.135                                  0.345
# ..                  ...                                    ...
# 395               0.025                                  0.323
# 396               0.000                                  0.233
# 397               0.039                                  0.269
# 398               0.003                                  0.277
# 399               0.000                                  0.195
#
#      _HarmonicChangeDetectionFunction_PeriodAmp
# 0                                         0.593
# 1                                         0.702
# 2                                         0.692
# 3                                         0.743
# 4                                         0.674
# ..                                          ...
# 395                                       0.867
# 396                                       0.879
# 397                                       0.819
# 398                                       0.811
# 399                                       0.848
#
# [400 rows x 14 columns]

# %%
data = data.replace("relax", 0) #basic way to replace strings in a dataset with numbers
data = data.replace("happy", 1)
data = data.replace("sad", 2)
data = data.replace("angry", 3)

df = data
df
# Out:
# /var/folders/wd/yv2kv5sn1kn30nq5ppyppw6r0000gn/T/ipykernel_25922/1367210064.py:4: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data = data.replace("angry", 3)
#      Class  _Fluctuation_Mean  _MFCC_Mean_2  _MFCC_Mean_4  _MFCC_Mean_7  \
# 0        0              9.136         0.363         0.078        -0.151
# 1        0              6.680         0.516         0.397        -0.403
# 2        0             10.578         0.903         0.329        -0.246
# 3        0             10.442         1.552         0.351         0.047
# 4        0              9.769         0.228         0.096         0.104
# ..     ...                ...           ...           ...           ...
# 395      3              5.265         0.065         0.046         0.198
# 396      3              5.042        -0.148        -0.011         0.065
# 397      3              4.724         0.566        -0.113         0.278
# 398      3              4.470        -0.210         0.089         0.173
# 399      3              5.343        -0.014        -0.021         0.310
#
#      _Roughness_Mean  _Roughness_Slope  _Zero-crossingrate_Mean  \
# 0             51.542             0.325                  403.129
# 1            336.839             0.366                  204.886
# 2             39.864             0.224                  685.474
# 3            353.744             0.215                  579.859
# 4             46.884            -0.118                  430.536
# ..               ...               ...                      ...
# 395          547.713             0.060                  493.908
# 396         1121.910             0.032                  975.308
# 397          889.926            -0.010                  916.985
# 398          408.726             0.174                  670.306
# 399          258.400            -0.000                  396.386
#
#      _AttackTime_Mean  _Eventdensity_Mean  _Pulseclarity_Mean  \
# 0               0.028               1.336               0.082
# 1               0.015               1.336               0.051
# 2               0.033               1.336               0.299
# 3               0.029               2.105               0.121
# 4               0.040               1.370               0.208
# ..                ...                 ...                 ...
# 395             0.025               4.076               0.514
# 396             0.014               3.687               0.589
# 397             0.017               2.940               0.077
# 398             0.025               2.539               0.317
# 399             0.017               4.744               0.258
#
#      _Chromagram_Mean_7  _HarmonicChangeDetectionFunction_Mean  \
# 0                 0.024                                  0.316
# 1                 0.120                                  0.285
# 2                 0.563                                  0.413
# 3                 0.276                                  0.422
# 4                 0.135                                  0.345
# ..                  ...                                    ...
# 395               0.025                                  0.323
# 396               0.000                                  0.233
# 397               0.039                                  0.269
# 398               0.003                                  0.277
# 399               0.000                                  0.195
#
#      _HarmonicChangeDetectionFunction_PeriodAmp
# 0                                         0.593
# 1                                         0.702
# 2                                         0.692
# 3                                         0.743
# 4                                         0.674
# ..                                          ...
# 395                                       0.867
# 396                                       0.879
# 397                                       0.819
# 398                                       0.811
# 399                                       0.848
#
# [400 rows x 14 columns]

# %%
X = df.drop(columns=["Class"])
y = df["Class"]

# %% [markdown]
# ## Data Clean Up ##

# %%
df = df.loc[:, ~data.map(lambda x: isinstance(x, str)).any(axis=0)] #axis=0 deletes any columns with string values
                                                                      #(string values can be encoded as numbers however, 
                                                                      #and decoded to be readable, think Natural Language Processing)

# %%
df = df.drop("", axis=1) #if predicting a string value then use this instead of above command

# %%
df = df.dropna(subset=["Class"], inplace=True) #drop rows with missing value from prediction column

# %%
df = df.drop_duplicates() #drop duplicate rows

# %%
from sklearn.preprocessing import StandardScaler
object = StandardScaler()

df = object.fit_transform(X)
# Out:
# array([[-0.30735512],
#        [-0.33207637],
#        [-0.33287946],
#        ...,
#        [-0.33309926],
#        [-0.33254977],
#        [-0.3307097 ]])

# %% [markdown]
# ## Data Analysis ##

# %%
df.corr()
# Out:
#                                                Class  _Fluctuation_Mean  \
# Class                                       1.000000          -0.347832
# _Fluctuation_Mean                          -0.347832           1.000000
# _MFCC_Mean_2                               -0.225821           0.074045
# _MFCC_Mean_4                               -0.137439           0.050983
# _MFCC_Mean_7                                0.235186          -0.232155
# _Roughness_Mean                             0.165123          -0.180095
# _Roughness_Slope                           -0.289729           0.016154
# _Zero-crossingrate_Mean                    -0.061988           0.042039
# _AttackTime_Mean                           -0.199196           0.236962
# _Eventdensity_Mean                          0.318354          -0.180546
# _Pulseclarity_Mean                          0.012549           0.015322
# _Chromagram_Mean_7                         -0.216149           0.138516
# _HarmonicChangeDetectionFunction_Mean      -0.369521           0.240051
# _HarmonicChangeDetectionFunction_PeriodAmp  0.351902          -0.233482
#
#                                             _MFCC_Mean_2  _MFCC_Mean_4  \
# Class                                          -0.225821     -0.137439
# _Fluctuation_Mean                               0.074045      0.050983
# _MFCC_Mean_2                                    1.000000      0.380148
# _MFCC_Mean_4                                    0.380148      1.000000
# _MFCC_Mean_7                                    0.056210      0.095366
# _Roughness_Mean                                -0.052287     -0.042914
# _Roughness_Slope                                0.126385      0.076530
# _Zero-crossingrate_Mean                        -0.263195     -0.247544
# _AttackTime_Mean                                0.047100     -0.112764
# _Eventdensity_Mean                             -0.179804     -0.048798
# _Pulseclarity_Mean                             -0.053653     -0.020949
# _Chromagram_Mean_7                             -0.028778     -0.046776
# _HarmonicChangeDetectionFunction_Mean          -0.037315     -0.070658
# _HarmonicChangeDetectionFunction_PeriodAmp     -0.144273      0.017734
#
#                                             _MFCC_Mean_7  _Roughness_Mean  \
# Class                                           0.235186         0.165123
# _Fluctuation_Mean                              -0.232155        -0.180095
# _MFCC_Mean_2                                    0.056210        -0.052287
# _MFCC_Mean_4                                    0.095366        -0.042914
# _MFCC_Mean_7                                    1.000000        -0.022768
# _Roughness_Mean                                -0.022768         1.000000
# _Roughness_Slope                               -0.080222        -0.103428
# _Zero-crossingrate_Mean                        -0.135895         0.159023
# _AttackTime_Mean                               -0.051157        -0.358394
# _Eventdensity_Mean                             -0.001004         0.460783
# _Pulseclarity_Mean                             -0.036471         0.232361
# _Chromagram_Mean_7                             -0.144348        -0.080568
# _HarmonicChangeDetectionFunction_Mean          -0.141267        -0.053615
# _HarmonicChangeDetectionFunction_PeriodAmp      0.058536         0.356988
#
#                                             _Roughness_Slope  \
# Class                                              -0.289729
# _Fluctuation_Mean                                   0.016154
# _MFCC_Mean_2                                        0.126385
# _MFCC_Mean_4                                        0.076530
# _MFCC_Mean_7                                       -0.080222
# _Roughness_Mean                                    -0.103428
# _Roughness_Slope                                    1.000000
# _Zero-crossingrate_Mean                            -0.049230
# _AttackTime_Mean                                    0.041976
# _Eventdensity_Mean                                 -0.189767
# _Pulseclarity_Mean                                 -0.115242
# _Chromagram_Mean_7                                  0.051439
# _HarmonicChangeDetectionFunction_Mean               0.109272
# _HarmonicChangeDetectionFunction_PeriodAmp         -0.165104
#
#                                             _Zero-crossingrate_Mean  \
# Class                                                     -0.061988
# _Fluctuation_Mean                                          0.042039
# _MFCC_Mean_2                                              -0.263195
# _MFCC_Mean_4                                              -0.247544
# _MFCC_Mean_7                                              -0.135895
# _Roughness_Mean                                            0.159023
# _Roughness_Slope                                          -0.049230
# _Zero-crossingrate_Mean                                    1.000000
# _AttackTime_Mean                                          -0.059268
# _Eventdensity_Mean                                         0.326648
# _Pulseclarity_Mean                                         0.426554
# _Chromagram_Mean_7                                         0.203020
# _HarmonicChangeDetectionFunction_Mean                      0.228185
# _HarmonicChangeDetectionFunction_PeriodAmp                 0.347395
#
#                                             _AttackTime_Mean  \
# Class                                              -0.199196
# _Fluctuation_Mean                                   0.236962
# _MFCC_Mean_2                                        0.047100
# _MFCC_Mean_4                                       -0.112764
# _MFCC_Mean_7                                       -0.051157
# _Roughness_Mean                                    -0.358394
# _Roughness_Slope                                    0.041976
# _Zero-crossingrate_Mean                            -0.059268
# _AttackTime_Mean                                    1.000000
# _Eventdensity_Mean                                 -0.535916
# _Pulseclarity_Mean                                 -0.206970
# _Chromagram_Mean_7                                  0.032394
# _HarmonicChangeDetectionFunction_Mean               0.010931
# _HarmonicChangeDetectionFunction_PeriodAmp         -0.435865
#
#                                             _Eventdensity_Mean  \
# Class                                                 0.318354
# _Fluctuation_Mean                                    -0.180546
# _MFCC_Mean_2                                         -0.179804
# _MFCC_Mean_4                                         -0.048798
# _MFCC_Mean_7                                         -0.001004
# _Roughness_Mean                                       0.460783
# _Roughness_Slope                                     -0.189767
# _Zero-crossingrate_Mean                               0.326648
# _AttackTime_Mean                                     -0.535916
# _Eventdensity_Mean                                    1.000000
# _Pulseclarity_Mean                                    0.411840
# _Chromagram_Mean_7                                   -0.086854
# _HarmonicChangeDetectionFunction_Mean                 0.019388
# _HarmonicChangeDetectionFunction_PeriodAmp            0.656621
#
#                                             _Pulseclarity_Mean  \
# Class                                                 0.012549
# _Fluctuation_Mean                                     0.015322
# _MFCC_Mean_2                                         -0.053653
# _MFCC_Mean_4                                         -0.020949
# _MFCC_Mean_7                                         -0.036471
# _Roughness_Mean                                       0.232361
# _Roughness_Slope                                     -0.115242
# _Zero-crossingrate_Mean                               0.426554
# _AttackTime_Mean                                     -0.206970
# _Eventdensity_Mean                                    0.411840
# _Pulseclarity_Mean                                    1.000000
# _Chromagram_Mean_7                                   -0.088090
# _HarmonicChangeDetectionFunction_Mean                 0.015317
# _HarmonicChangeDetectionFunction_PeriodAmp            0.441480
#
#                                             _Chromagram_Mean_7  \
# Class                                                -0.216149
# _Fluctuation_Mean                                     0.138516
# _MFCC_Mean_2                                         -0.028778
# _MFCC_Mean_4                                         -0.046776
# _MFCC_Mean_7                                         -0.144348
# _Roughness_Mean                                      -0.080568
# _Roughness_Slope                                      0.051439
# _Zero-crossingrate_Mean                               0.203020
# _AttackTime_Mean                                      0.032394
# _Eventdensity_Mean                                   -0.086854
# _Pulseclarity_Mean                                   -0.088090
# _Chromagram_Mean_7                                    1.000000
# _HarmonicChangeDetectionFunction_Mean                 0.300982
# _HarmonicChangeDetectionFunction_PeriodAmp           -0.041825
#
#                                             _HarmonicChangeDetectionFunction_Mean  \
# Class                                                                   -0.369521
# _Fluctuation_Mean                                                        0.240051
# _MFCC_Mean_2                                                            -0.037315
# _MFCC_Mean_4                                                            -0.070658
# _MFCC_Mean_7                                                            -0.141267
# _Roughness_Mean                                                         -0.053615
# _Roughness_Slope                                                         0.109272
# _Zero-crossingrate_Mean                                                  0.228185
# _AttackTime_Mean                                                         0.010931
# _Eventdensity_Mean                                                       0.019388
# _Pulseclarity_Mean                                                       0.015317
# _Chromagram_Mean_7                                                       0.300982
# _HarmonicChangeDetectionFunction_Mean                                    1.000000
# _HarmonicChangeDetectionFunction_PeriodAmp                               0.154422
#
#                                             _HarmonicChangeDetectionFunction_PeriodAmp
# Class                                                                         0.351902
# _Fluctuation_Mean                                                            -0.233482
# _MFCC_Mean_2                                                                 -0.144273
# _MFCC_Mean_4                                                                  0.017734
# _MFCC_Mean_7                                                                  0.058536
# _Roughness_Mean                                                               0.356988
# _Roughness_Slope                                                             -0.165104
# _Zero-crossingrate_Mean                                                       0.347395
# _AttackTime_Mean                                                             -0.435865
# _Eventdensity_Mean                                                            0.656621
# _Pulseclarity_Mean                                                            0.441480
# _Chromagram_Mean_7                                                           -0.041825
# _HarmonicChangeDetectionFunction_Mean                                         0.154422
# _HarmonicChangeDetectionFunction_PeriodAmp                                    1.000000

# %%
from scipy.stats import *

kstest(X, "norm").pvalue
# Out:
# array([0.00000000e+000, 1.31168822e-014, 5.36061441e-034, 2.64882187e-049,
#        0.00000000e+000, 3.81923763e-049, 0.00000000e+000, 1.38810961e-094,
#        4.77948146e-268, 2.12902772e-097, 5.39013148e-093, 2.80889193e-122,
#        8.78796579e-202])

# %%
stats.zscore(df)
# Out:
# /var/folders/wd/yv2kv5sn1kn30nq5ppyppw6r0000gn/T/ipykernel_14159/2044279499.py:1: DeprecationWarning: Please import `zscore` from the `scipy.stats` namespace; the `scipy.stats.stats` namespace is deprecated and will be removed in SciPy 2.0.0.
#   stats.zscore(df)
#         Class  _Fluctuation_Mean  _MFCC_Mean_2  _MFCC_Mean_4  _MFCC_Mean_7  \
# 0   -1.341641           0.873874      0.541910      0.172545     -1.167006
# 1   -1.341641          -0.204599      0.826724      1.330466     -2.561155
# 2   -1.341641           1.507082      1.547136      1.083636     -1.692578
# 3   -1.341641           1.447362      2.755269      1.163493     -0.071602
# 4   -1.341641           1.151836      0.290603      0.237882      0.243741
# ..        ...                ...           ...           ...           ...
# 395  1.341641          -0.825951     -0.012826      0.056390      0.763781
# 396  1.341641          -0.923874     -0.409332     -0.150512      0.027980
# 397  1.341641          -1.063514      0.919800     -0.520756      1.206368
# 398  1.341641          -1.175050     -0.524747      0.212473      0.625472
# 399  1.341641          -0.791700     -0.159887     -0.186810      1.383403
#
#      _Roughness_Mean  _Roughness_Slope  _Zero-crossingrate_Mean  \
# 0          -0.914655          1.453111                -1.133305
# 1          -0.366605          1.688630                -1.511459
# 2          -0.937089          0.872929                -0.594725
# 3          -0.334131          0.821230                -0.796188
# 4          -0.923603         -1.091646                -1.081026
# ..               ...               ...                      ...
# 395         0.038480         -0.069148                -0.960142
# 396         1.141503         -0.229990                -0.041859
# 397         0.695866         -0.471254                -0.153112
# 398        -0.228511          0.585711                -0.623658
# 399        -0.517285         -0.413810                -1.146168
#
#      _AttackTime_Mean  _Eventdensity_Mean  _Pulseclarity_Mean  \
# 0           -0.196958           -1.093260           -1.078941
# 1           -0.971678           -1.093260           -1.278759
# 2            0.101012           -1.093260            0.319791
# 3           -0.137364           -0.512983           -0.827556
# 4            0.518169           -1.067604           -0.266774
# ..                ...                 ...                 ...
# 395         -0.375739            0.974307            1.705630
# 396         -1.031272            0.680773            2.189063
# 397         -0.852490            0.117097           -1.111169
# 398         -0.375739           -0.185492            0.435814
# 399         -0.852490            1.478371            0.055514
#
#      _Chromagram_Mean_7  _HarmonicChangeDetectionFunction_Mean  \
# 0             -0.794326                              -0.220241
# 1             -0.445806                              -0.779298
# 2              1.162468                               1.529065
# 3              0.120539                               1.691372
# 4             -0.391350                               0.302747
# ..                  ...                                    ...
# 395           -0.790695                              -0.094003
# 396           -0.881455                              -1.717071
# 397           -0.739869                              -1.067844
# 398           -0.870564                              -0.923571
# 399           -0.881455                              -2.402366
#
#      _HarmonicChangeDetectionFunction_PeriodAmp
# 0                                     -2.453450
# 1                                     -0.939917
# 2                                     -1.078774
# 3                                     -0.370607
# 4                                     -1.328715
# ..                                          ...
# 395                                    1.351209
# 396                                    1.517837
# 397                                    0.684700
# 398                                    0.573615
# 399                                    1.087383
#
# [400 rows x 14 columns]

# %%
z = np.abs(stats.zscore(df))
threshold_z = 3
outlier_indices = np.where(z > threshold_z)[0]
df = df.drop(outlier_indices)
df.shape

# %%
import matplotlib.pyplot as plt
import seaborn as sn

# %% [markdown]
# ## Data Optimization ##

# %%
import numpy as np

a = 1
z = 3
d = df.iloc[0:388, a:z] #[Rows, Columns]
f = np.array([[12, 3, 4], [5, 1, 2]]) #Matrix
vec_df = np.dot(d, 0.5) #Operations to weight data

v = pd.DataFrame(vec_df, columns = df.columns[a:z].tolist())
df.update(v)

# %%
a = 6
z = 8
d = df.iloc[0:388, a:z] #[Rows, Columns]
f = np.array([[12, 3, 4], [5, 1, 2]]) #Matrix
vec_df = np.dot(d, 0.5) #Operations to weight data

v = pd.DataFrame(vec_df, columns = df.columns[a:z].tolist())
df.update(v)

# %%
a = 11
z = 12
d = df.iloc[0:388, a:z] #[Rows, Columns]
f = np.array([[12, 3, 4], [5, 1, 2]]) #Matrix
vec_df = np.dot(d, 0.5) #Operations to weight data

v = pd.DataFrame(vec_df, columns = df.columns[a:z].tolist())
df.update(v)

# %%
a = 4
z = 5
d = df.iloc[0:388, a:z] #[Rows, Columns]
f = np.array([[12, 3, 4], [5, 1, 2]]) #Matrix
vec_df = np.dot(d, 3) #Operations to weight data

v = pd.DataFrame(vec_df, columns = df.columns[a:z].tolist())
df.update(v)

# %%
a = 9
z = 10
d = df.iloc[0:388, a:z] #[Rows, Columns]
f = np.array([[12, 3, 4], [5, 1, 2]]) #Matrix
vec_df = np.dot(d, 3) #Operations to weight data

v = pd.DataFrame(vec_df, columns = df.columns[a:z].tolist())
df.update(v)

# %%
a = 12
z = 14
d = df.iloc[0:388, a:z] #[Rows, Columns]
f = np.array([[12, 3, 4], [5, 1, 2]]) #Matrix
vec_df = np.dot(d, 3) #Operations to weight data

v = pd.DataFrame(vec_df, columns = df.columns[a:z].tolist())
df.update(v)

# %%
a = 12
z = 14
d = df.iloc[0:388, a:z] #[Rows, Columns]
f = np.array([[12, 3, 4], [5, 1, 2]]) #Matrix
vec_df = np.dot(d, 1/3)

v = pd.DataFrame(vec_df, columns = df.columns[a:z].tolist())
df.update(v)

# %%
#re-inserting weighted data back into the dataset
df
# Out:
#      Class  _Fluctuation_Mean  _MFCC_Mean_2  _MFCC_Mean_4  _MFCC_Mean_7  \
# 0        0             4.5680        0.1815         0.078        -0.453
# 1        0             3.3400        0.2580         0.397        -1.209
# 2        0             5.2890        0.4515         0.329        -0.738
# 3        0             5.2210        0.7760         0.351         0.141
# 4        0             4.8845        0.1140         0.096         0.312
# ..     ...                ...           ...           ...           ...
# 395      3             5.2650        0.0650         0.046         0.198
# 396      3             5.0420       -0.1480        -0.011         0.065
# 397      3             4.7240        0.5660        -0.113         0.278
# 398      3             4.4700       -0.2100         0.089         0.173
# 399      3             5.3430       -0.0140        -0.021         0.310
#
#      _Roughness_Mean  _Roughness_Slope  _Zero-crossingrate_Mean  \
# 0             51.542            0.1625                 201.5645
# 1            336.839            0.1830                 102.4430
# 2             39.864            0.1120                 342.7370
# 3            353.744            0.1075                 289.9295
# 4             46.884           -0.0590                 215.2680
# ..               ...               ...                      ...
# 395          547.713            0.0600                 493.9080
# 396         1121.910            0.0320                 975.3080
# 397          889.926           -0.0100                 916.9850
# 398          408.726            0.1740                 670.3060
# 399          258.400           -0.0000                 396.3860
#
#      _AttackTime_Mean  _Eventdensity_Mean  _Pulseclarity_Mean  \
# 0               0.028               4.008               0.082
# 1               0.015               4.008               0.051
# 2               0.033               4.008               0.299
# 3               0.029               6.315               0.121
# 4               0.040               4.110               0.208
# ..                ...                 ...                 ...
# 395             0.025               4.076               0.514
# 396             0.014               3.687               0.589
# 397             0.017               2.940               0.077
# 398             0.025               2.539               0.317
# 399             0.017               4.744               0.258
#
#      _Chromagram_Mean_7  _HarmonicChangeDetectionFunction_Mean  \
# 0                0.0120                                  0.948
# 1                0.0600                                  0.855
# 2                0.2815                                  1.239
# 3                0.1380                                  1.266
# 4                0.0675                                  1.035
# ..                  ...                                    ...
# 395              0.0250                                  0.323
# 396              0.0000                                  0.233
# 397              0.0390                                  0.269
# 398              0.0030                                  0.277
# 399              0.0000                                  0.195
#
#      _HarmonicChangeDetectionFunction_PeriodAmp
# 0                                         1.779
# 1                                         2.106
# 2                                         2.076
# 3                                         2.229
# 4                                         2.022
# ..                                          ...
# 395                                       0.867
# 396                                       0.879
# 397                                       0.819
# 398                                       0.811
# 399                                       0.848
#
# [400 rows x 14 columns]

# %% [markdown]
# ## Fine-Tuning ##

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 0)

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import mean_squared_error
from bayes_opt import BayesianOptimization
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import train_test_split

# Define the function to optimize using cross-validation
def dtree_cv(max_depth, min_samples_split, min_samples_leaf):
    # Define the model with the parameters to be optimized
    estimator = RandomForestRegressor(
        max_depth=int(max_depth),
        min_samples_split=int(min_samples_split),
        min_samples_leaf=int(min_samples_leaf),
        random_state=2
    )
    cval = cross_val_score(estimator, X_train, y_train, scoring='neg_mean_squared_error', cv=5)
    return cval.mean() # The optimizer tries to maximize the function, so we negate the score to minimize it

# Define the parameter bounds
param_bounds = {
    'max_depth': (1, 20),
    'min_samples_split': (2, 20),
    'min_samples_leaf': (1, 20)
}

optimizer = BayesianOptimization(
    f=dtree_cv,
    pbounds=param_bounds,
    random_state=1,
)

optimizer.maximize(n_iter=100, init_points=6) # Bayesian optimization
best_params_bayes = optimizer.max['params']
best_params_bayes['max_depth'] = int(best_params_bayes['max_depth'])
best_params_bayes['min_samples_split'] = int(best_params_bayes['min_samples_split'])
best_params_bayes['min_samples_leaf'] = int(best_params_bayes['min_samples_leaf'])
best_score_bayes = optimizer.max['target']

print(f"Best Parameters (Bayesian Optimization): {best_params_bayes}")
print(f"Best Score (Bayesian Optimization): {best_score_bayes}")
# Out:
# |   iter    |  target   | max_depth | min_sa... | min_sa... |
# -------------------------------------------------------------
# | 1         | -0.729    | 8.923     | 14.69     | 2.002     |
# | 2         | -0.6853   | 6.744     | 3.788     | 3.662     |
# | 3         | -0.7063   | 4.539     | 7.566     | 9.142     |
# | 4         | -0.6992   | 11.24     | 8.965     | 14.33     |
# | 5         | -0.7449   | 4.885     | 17.68     | 2.493     |
# | 6         | -0.6992   | 13.74     | 8.929     | 12.06     |
# | 7         | -0.6924   | 16.23     | 1.149     | 2.744     |
# | 8         | -0.7116   | 19.92     | 1.083     | 19.25     |
# | 9         | -0.702    | 10.61     | 1.005     | 9.052     |
# | 10        | -0.8821   | 1.359     | 1.362     | 2.342     |
# | 11        | -0.6787   | 8.948     | 3.397     | 5.39      |
# | 12        | -0.6904   | 11.32     | 6.421     | 2.157     |
# | 13        | -0.6904   | 17.49     | 6.184     | 5.965     |
# | 14        | -0.7016   | 18.59     | 1.091     | 9.724     |
# | 15        | -0.7189   | 19.75     | 12.83     | 6.774     |
# | 16        | -0.6991   | 9.638     | 8.669     | 6.333     |
# | 17        | -0.7145   | 16.49     | 11.83     | 19.86     |
# | 18        | -0.7069   | 9.104     | 2.376     | 18.51     |
# | 19        | -0.7148   | 4.197     | 10.72     | 18.6      |
# | 20        | -0.6911   | 11.43     | 1.739     | 2.022     |
# | 21        | -0.7497   | 10.99     | 19.78     | 16.67     |
# | 22        | -0.8821   | 1.044     | 1.503     | 18.72     |
# | 23        | -0.8821   | 1.154     | 18.84     | 18.9      |
# | 24        | -0.7497   | 19.97     | 19.89     | 16.98     |
# | 25        | -0.7497   | 19.47     | 19.84     | 2.397     |
# | 26        | -0.6984   | 13.95     | 4.364     | 19.9      |
# | 27        | -0.6975   | 19.97     | 7.308     | 14.23     |
# | 28        | -0.7066   | 14.95     | 1.497     | 14.83     |
# | 29        | -0.6904   | 19.74     | 6.588     | 2.058     |
# | 30        | -0.7073   | 9.685     | 9.456     | 19.93     |
# | 31        | -0.7072   | 5.671     | 9.084     | 2.136     |
# | 32        | -0.7026   | 20.0      | 1.42      | 4.933     |
# | 33        | -0.7497   | 12.4      | 19.78     | 8.381     |
# | 34        | -0.7059   | 19.81     | 7.406     | 19.84     |
# | 35        | -0.686    | 9.704     | 5.13      | 11.68     |
# | 36        | -0.7145   | 16.25     | 11.84     | 2.383     |
# | 37        | -0.7145   | 6.148     | 11.3      | 12.14     |
# | 38        | -0.6904   | 19.9      | 6.649     | 9.36      |
# | 39        | -0.678    | 13.69     | 4.265     | 8.585     |
# | 40        | -0.7189   | 19.95     | 12.99     | 14.35     |
# | 41        | -0.6844   | 7.943     | 5.838     | 4.285     |
# | 42        | -0.6972   | 11.09     | 5.002     | 16.18     |
# | 43        | -0.6775   | 13.19     | 3.906     | 4.834     |
# | 44        | -0.678    | 15.87     | 4.768     | 2.031     |
# | 45        | -0.688    | 16.24     | 4.775     | 11.78     |
# | 46        | -0.7017   | 6.895     | 7.752     | 15.02     |
# | 47        | -0.682    | 11.02     | 5.576     | 7.88      |
# | 48        | -0.6787   | 8.408     | 4.35      | 2.15      |
# | 49        | -0.7113   | 13.33     | 1.313     | 19.77     |
# | 50        | -0.705    | 19.99     | 2.548     | 14.53     |
# | 51        | -0.6919   | 15.69     | 2.173     | 6.338     |
# | 52        | -0.6775   | 18.08     | 3.469     | 2.016     |
# | 53        | -0.6975   | 14.29     | 7.32      | 7.367     |
# | 54        | -0.684    | 12.63     | 4.573     | 10.95     |
# | 55        | -0.6792   | 7.43      | 4.926     | 8.077     |
# | 56        | -0.6977   | 8.643     | 7.103     | 9.741     |
# | 57        | -0.6992   | 15.61     | 8.268     | 16.37     |
# | 58        | -0.6942   | 19.71     | 2.062     | 2.065     |
# | 59        | -0.6791   | 11.93     | 3.415     | 7.415     |
# | 60        | -0.6887   | 7.282     | 3.279     | 10.53     |
# | 61        | -0.678    | 17.0      | 4.226     | 3.532     |
# | 62        | -0.6772   | 10.81     | 3.884     | 3.121     |
# | 63        | -0.678    | 13.29     | 4.096     | 2.145     |
# | 64        | -0.6839   | 8.901     | 3.722     | 8.223     |
# | 65        | -0.7019   | 10.1      | 2.437     | 13.63     |
# | 66        | -0.678    | 19.89     | 4.181     | 7.484     |
# | 67        | -0.678    | 18.31     | 4.182     | 8.685     |
# | 68        | -0.688    | 19.87     | 4.363     | 11.06     |
# | 69        | -0.678    | 19.73     | 4.34      | 3.998     |
# | 70        | -0.6775   | 15.53     | 3.416     | 2.147     |
# | 71        | -0.6781   | 11.37     | 4.705     | 4.998     |
# | 72        | -0.6787   | 8.581     | 3.886     | 3.852     |
# | 73        | -0.6858   | 5.856     | 4.515     | 7.022     |
# | 74        | -0.6775   | 18.48     | 3.833     | 6.429     |
# | 75        | -0.682    | 19.96     | 5.278     | 5.541     |
# | 76        | -0.678    | 13.26     | 4.814     | 6.538     |
# | 77        | -0.6771   | 11.07     | 3.003     | 5.173     |
# | 78        | -0.678    | 16.34     | 4.381     | 8.361     |
# | 79        | -0.678    | 17.65     | 4.583     | 2.021     |
# | 80        | -0.6844   | 7.377     | 5.068     | 6.745     |
# | 81        | -0.7255   | 13.0      | 13.84     | 13.67     |
# | 82        | -0.6844   | 6.868     | 4.564     | 9.417     |
# | 83        | -0.8821   | 1.055     | 12.39     | 6.692     |
# | 84        | -0.7497   | 8.578     | 19.65     | 2.039     |
# | 85        | -0.6918   | 7.423     | 6.716     | 2.099     |
# | 86        | -0.7145   | 7.55      | 11.85     | 16.58     |
# | 87        | -0.7003   | 8.57      | 1.212     | 5.012     |
# | 88        | -0.6999   | 8.402     | 5.064     | 20.0      |
# | 89        | -0.7497   | 19.95     | 19.62     | 10.41     |
# | 90        | -0.6972   | 17.27     | 5.103     | 16.96     |
# | 91        | -0.6828   | 14.76     | 3.031     | 9.837     |
# | 92        | -0.682    | 14.29     | 5.205     | 3.949     |
# | 93        | -0.7145   | 19.81     | 11.55     | 2.211     |
# | 94        | -0.6775   | 12.57     | 3.299     | 3.742     |
# | 95        | -0.6775   | 18.51     | 3.707     | 3.627     |
# | 96        | -0.678    | 15.95     | 4.415     | 6.169     |
# | 97        | -0.6781   | 11.29     | 4.046     | 6.391     |
# | 98        | -0.6794   | 13.6      | 3.819     | 7.384     |
# | 99        | -0.6999   | 11.12     | 5.985     | 19.99     |
# | 100       | -0.6814   | 11.61     | 4.3       | 9.172     |
# | 101       | -0.678    | 19.98     | 4.308     | 2.704     |
# | 102       | -0.678    | 17.43     | 4.309     | 7.31      |
# | 103       | -0.682    | 14.47     | 5.33      | 9.72      |
# | 104       | -0.6775   | 15.02     | 3.454     | 3.56      |
# | 105       | -0.678    | 10.76     | 4.404     | 2.038     |
# | 106       | -0.6772   | 10.27     | 3.815     | 4.74      |
# =============================================================
# Best Parameters (Bayesian Optimization): {'max_depth': 11, 'min_samples_leaf': 3, 'min_samples_split': 5}
# Best Score (Bayesian Optimization): -0.677117836879144

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import mean_squared_error
from bayes_opt import BayesianOptimization
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import train_test_split

# Define the function to optimize using cross-validation
def dtree_cv(max_depth, min_samples_split, min_samples_leaf):
    # Define the model with the parameters to be optimized
    estimator = DecisionTreeClassifier(
        max_depth=int(max_depth),
        min_samples_split=int(min_samples_split),
        min_samples_leaf=int(min_samples_leaf),
        random_state=2
    )
    cval = cross_val_score(estimator, X_train, y_train, scoring='neg_mean_squared_error', cv=5)
    return cval.mean() # The optimizer tries to maximize the function, so we negate the score to minimize it

# Define the parameter bounds
param_bounds = {
    'max_depth': (1, 20),
    'min_samples_split': (2, 20),
    'min_samples_leaf': (1, 20)
}

optimizer = BayesianOptimization(
    f=dtree_cv,
    pbounds=param_bounds,
    random_state=1,
)

optimizer.maximize(n_iter=100, init_points=6) # Bayesian optimization
best_params_bayes = optimizer.max['params']
best_params_bayes['max_depth'] = int(best_params_bayes['max_depth'])
best_params_bayes['min_samples_split'] = int(best_params_bayes['min_samples_split'])
best_params_bayes['min_samples_leaf'] = int(best_params_bayes['min_samples_leaf'])
best_score_bayes = optimizer.max['target']

print(f"Best Parameters (Bayesian Optimization): {best_params_bayes}")
print(f"Best Score (Bayesian Optimization): {best_score_bayes}")
# Out:
# |   iter    |  target   | max_depth | min_sa... | min_sa... |
# -------------------------------------------------------------
# | 1         | -1.303    | 8.923     | 14.69     | 2.002     |
# | 2         | -1.269    | 6.744     | 3.788     | 3.662     |
# | 3         | -1.255    | 4.539     | 7.566     | 9.142     |
# | 4         | -1.14     | 11.24     | 8.965     | 14.33     |
# | 5         | -1.275    | 4.885     | 17.68     | 2.493     |
# | 6         | -1.14     | 13.74     | 8.929     | 12.06     |
# | 7         | -1.303    | 18.77     | 7.454     | 19.55     |
# | 8         | -1.304    | 12.19     | 13.44     | 13.27     |
# | 9         | -1.214    | 12.24     | 7.183     | 13.04     |
# | 10        | -1.273    | 13.07     | 9.425     | 13.8      |
# | 11        | -1.303    | 14.8      | 14.84     | 5.504     |
# | 12        | -1.273    | 9.935     | 9.046     | 10.49     |
# | 13        | -1.304    | 19.15     | 13.62     | 10.47     |
# | 14        | -1.216    | 10.29     | 16.98     | 19.62     |
# | 15        | -1.303    | 7.127     | 15.51     | 17.43     |
# | 16        | -1.303    | 17.24     | 14.67     | 18.42     |
# | 17        | -1.278    | 13.87     | 11.41     | 8.898     |
# | 18        | -1.364    | 3.674     | 3.648     | 7.703     |
# | 19        | -1.14     | 11.48     | 8.225     | 14.17     |
# | 20        | -1.14     | 10.77     | 8.354     | 13.6      |
# | 21        | -1.14     | 10.52     | 8.243     | 15.03     |
# | 22        | -1.14     | 14.41     | 8.112     | 10.9      |
# | 23        | -1.214    | 15.79     | 7.627     | 12.19     |
# | 24        | -1.273    | 14.69     | 9.553     | 10.74     |
# | 25        | -1.214    | 13.51     | 7.502     | 11.52     |
# | 26        | -1.273    | 9.367     | 9.042     | 14.97     |
# | 27        | -1.14     | 11.73     | 8.415     | 15.47     |
# | 28        | -1.214    | 10.98     | 7.111     | 14.73     |
# | 29        | -1.273    | 11.19     | 9.36      | 15.5      |
# | 30        | -1.14     | 14.88     | 8.399     | 11.82     |
# | 31        | -1.2      | 12.64     | 7.95      | 15.13     |
# | 32        | -1.2      | 10.94     | 7.926     | 16.31     |
# | 33        | -1.14     | 14.25     | 8.425     | 12.76     |
# | 34        | -1.273    | 10.99     | 9.529     | 13.21     |
# | 35        | -1.14     | 10.92     | 8.471     | 14.3      |
# | 36        | -1.14     | 14.2      | 8.14      | 12.12     |
# | 37        | -1.214    | 15.25     | 7.293     | 10.71     |
# | 38        | -1.214    | 10.64     | 7.589     | 12.81     |
# | 39        | -1.273    | 15.33     | 9.236     | 12.67     |
# | 40        | -1.214    | 14.49     | 7.229     | 13.55     |
# | 41        | -1.214    | 13.36     | 7.957     | 10.09     |
# | 42        | -1.14     | 14.32     | 8.749     | 11.56     |
# | 43        | -1.229    | 12.71     | 7.527     | 17.09     |
# | 44        | -1.14     | 13.04     | 8.472     | 12.49     |
# | 45        | -1.231    | 12.48     | 18.53     | 19.48     |
# | 46        | -1.14     | 13.1      | 8.818     | 11.18     |
# | 47        | -1.14     | 12.24     | 8.241     | 11.89     |
# | 48        | -1.273    | 12.53     | 9.569     | 11.24     |
# | 49        | -1.214    | 11.45     | 7.611     | 11.07     |
# | 50        | -1.14     | 11.62     | 8.322     | 12.87     |
# | 51        | -1.816    | 1.106     | 1.477     | 19.75     |
# | 52        | -1.411    | 19.3      | 1.325     | 2.747     |
# | 53        | -1.816    | 1.041     | 19.48     | 12.07     |
# | 54        | -1.271    | 13.2      | 19.83     | 12.5      |
# | 55        | -1.271    | 19.97     | 19.92     | 3.61      |
# | 56        | -1.816    | 1.418     | 11.31     | 2.417     |
# | 57        | -1.345    | 13.36     | 1.108     | 19.81     |
# | 58        | -1.278    | 19.86     | 11.2      | 2.153     |
# | 59        | -1.271    | 19.9      | 19.8      | 14.78     |
# | 60        | -1.174    | 12.48     | 6.873     | 2.036     |
# | 61        | -1.369    | 11.68     | 3.292     | 2.115     |
# | 62        | -1.273    | 13.54     | 9.832     | 2.568     |
# | 63        | -1.14     | 9.505     | 8.803     | 2.074     |
# | 64        | -1.214    | 9.724     | 7.85      | 5.333     |
# | 65        | -1.356    | 19.4      | 1.171     | 13.05     |
# | 66        | -1.816    | 1.142     | 12.44     | 19.88     |
# | 67        | -1.271    | 9.835     | 19.88     | 7.253     |
# | 68        | -1.271    | 19.59     | 19.99     | 9.385     |
# | 69        | -1.271    | 7.613     | 19.91     | 19.75     |
# | 70        | -1.271    | 13.29     | 19.45     | 2.049     |
# | 71        | -1.816    | 1.012     | 1.097     | 2.461     |
# | 72        | -1.271    | 18.72     | 19.72     | 19.26     |
# | 73        | -1.231    | 10.31     | 18.54     | 15.79     |
# | 74        | -1.345    | 19.53     | 1.901     | 19.98     |
# | 75        | -1.278    | 8.453     | 11.67     | 5.945     |
# | 76        | -1.214    | 19.94     | 7.541     | 6.962     |
# | 77        | -1.214    | 16.33     | 7.217     | 4.949     |
# | 78        | -1.376    | 10.22     | 1.018     | 9.179     |
# | 79        | -1.248    | 8.107     | 6.314     | 2.006     |
# | 80        | -1.216    | 9.596     | 16.64     | 11.5      |
# | 81        | -1.816    | 1.002     | 7.011     | 12.09     |
# | 82        | -1.174    | 19.98     | 6.759     | 2.584     |
# | 83        | -1.216    | 13.9      | 16.39     | 10.08     |
# | 84        | -1.271    | 15.73     | 19.82     | 6.854     |
# | 85        | -1.245    | 15.11     | 17.27     | 15.03     |
# | 86        | -1.303    | 19.95     | 14.96     | 6.016     |
# | 87        | -1.26     | 16.8      | 5.578     | 2.121     |
# | 88        | -1.303    | 10.67     | 15.44     | 8.103     |
# | 89        | -1.816    | 1.035     | 19.97     | 3.412     |
# | 90        | -1.271    | 8.85      | 19.77     | 2.199     |
# | 91        | -1.28     | 19.87     | 3.934     | 7.631     |
# | 92        | -1.277    | 7.479     | 6.747     | 7.869     |
# | 93        | -1.148    | 17.44     | 10.69     | 5.561     |
# | 94        | -1.14     | 19.72     | 8.727     | 4.674     |
# | 95        | -1.148    | 19.31     | 10.95     | 7.366     |
# | 96        | -1.264    | 8.177     | 1.065     | 14.97     |
# | 97        | -1.271    | 8.205     | 19.99     | 12.41     |
# | 98        | -1.34     | 9.023     | 4.218     | 19.98     |
# | 99        | -1.303    | 12.63     | 14.16     | 19.87     |
# | 100       | -1.557    | 2.495     | 19.95     | 19.83     |
# | 101       | -1.319    | 5.942     | 12.63     | 9.794     |
# | 102       | -1.278    | 19.95     | 11.73     | 19.88     |
# | 103       | -1.245    | 17.58     | 17.15     | 2.105     |
# | 104       | -1.303    | 19.97     | 14.07     | 14.98     |
# | 105       | -1.273    | 17.42     | 9.201     | 7.505     |
# | 106       | -1.273    | 17.8      | 9.261     | 2.82      |
# =============================================================
# Best Parameters (Bayesian Optimization): {'max_depth': 11, 'min_samples_leaf': 8, 'min_samples_split': 14}
# Best Score (Bayesian Optimization): -1.1400000000000001

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import KFold

kf = KFold(n_splits=5,shuffle=True,random_state=42)
parameter={'n_neighbors': np.arange(2, 30, 1)}
knn=KNeighborsClassifier()
knn_cv=GridSearchCV(knn, param_grid=parameter, cv=kf, verbose=1)
knn_cv.fit(X_train, y_train)
print(knn_cv.best_params_)
# Out:
# Fitting 5 folds for each of 28 candidates, totalling 140 fits
# {'n_neighbors': 19}

# %% [markdown]
# ## Training and Testing ##

# %%
from sklearn.ensemble import RandomForestClassifier
import joblib

model1 = RandomForestClassifier(max_depth = 18, min_samples_leaf = 1, min_samples_split = 2).fit(X_train, y_train)

predictions = model1.predict(X_test)
score = accuracy_score(y_test, predictions)
print(f"Accuracy: {score}")

#Save Model
if score >= 0.8:
    joblib.dump(model1, "test.joblib")
    model = joblib.load("test.joblib")
# Out:
# Accuracy: 0.8333333333333334

# %%
from sklearn.tree import DecisionTreeClassifier

model2 = DecisionTreeClassifier(max_depth = 11, min_samples_leaf = 8, min_samples_split = 14).fit(X_train, y_train)

#Save Model
#joblib.dump(model2, ".joblib")
#model = joblib.load(".joblib")

predictions = model2.predict(X_test)
score = accuracy_score(y_test, predictions)
print(f"Accuracy: {score}")
# Out:
# Accuracy: 0.7083333333333334

# %%
from sklearn.neighbors import KNeighborsClassifier

model3 = KNeighborsClassifier(n_neighbors=19).fit(X_train, y_train)

#Save Model
#joblib.dump(model3, ".joblib")
#model = joblib.load(".joblib")

score = model3.score(X_test, y_test)
print(f"Accuracy: {score}")
# Out:
# Accuracy: 0.5166666666666667

# %%
from sklearn import svm

model4 = svm.SVC().fit(X_train, y_train)

#Save Model
#joblib.dump(model4, ".joblib")
#model = joblib.load(".joblib")

predictions = model4.predict(X_test)
score = accuracy_score(y_test, predictions)
print(f"Accuracy: {score}")
# Out:
# Accuracy: 0.55

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import GridSearchCV
import numpy as np

model4 = LinearRegression()

param_space = {'copy_X': [True,False], 'fit_intercept': [True,False], 
               'n_jobs': [1,5,10,15,None], 'positive': [True,False]}

grid_search2 = GridSearchCV(model4, param_space, cv=10).fit(X_train, y_train)

#Save Model
#joblib.dump(grid_search2, ".joblib")
#model = joblib.load(".joblib")

predictions = np.array(grid_search2.predict(X_test))
score = grid_search2.score(X_test, y_test)
print(f"Accuracy: {score}")
# Out:
# Accuracy: 0.47566465239241684

# %% [markdown]
# ## Predicted vs Actual ##

# %%
y_predicted = model.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_predicted)
cm
# Out:
# array([[24,  2,  7,  0],
#        [ 0, 28,  0,  2],
#        [ 6,  1, 18,  1],
#        [ 0,  0,  1, 30]])

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sn

plt.figure(figsize=(10, 7))
sn.heatmap(cm, annot=True)
plt.xlabel("Predicted")
plt.ylabel("Actual")
# Out:
# Text(95.72222222222221, 0.5, 'Actual')

# %%
predictions = model.predict([[0.2, .6, .4,0.2, .6, .4,0.2, .6, .4,0.2, .6, .4, .7]])
print(predictions, f"\nAccuracy: {score}")
# Out:
# [0]
# Accuracy: 0.8333333333333334
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
