# %% [markdown]
# ## Import Data ##

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.optim import Adam
from torch.utils.data import Dataset, DataLoader
from torchinfo import summary
from torchvision.transforms import transforms
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt
import seaborn as sn
import librosa
import librosa.display
import pandas as pd
import numpy as np
from scipy.stats import *
import random
import time
from skimage.transform import resize
import warnings
import os

warnings.filterwarnings("ignore", category=DeprecationWarning)
warnings.simplefilter("ignore", category=UserWarning)

device = "mps" if torch.mps.is_available() else "cpu"
print(device)
# Out:
# mps

# %%
audio_path = []
labels = []

dir_path = os.getcwd()

for i in os.listdir(f"{dir_path}/shords_dataset"):
    for label in os.listdir(f"{dir_path}/shords_dataset/{i}"):
        for audio in os.listdir(f"{dir_path}/shords_dataset/{i}"):
            audio_path.append(f"{dir_path}/shords_dataset/{i}/{audio}")
            labels.append(i)

df = pd.DataFrame(zip(audio_path, labels), columns = ["audio_path", "Labels"])
df = df.drop_duplicates().reset_index(drop=True)
df
# Out:
#                                             audio_path Labels
# 0    /Users/jay/Jupyter Projects/Guitar/shords_data...  major
# 1    /Users/jay/Jupyter Projects/Guitar/shords_data...  major
# 2    /Users/jay/Jupyter Projects/Guitar/shords_data...  major
# 3    /Users/jay/Jupyter Projects/Guitar/shords_data...  major
# 4    /Users/jay/Jupyter Projects/Guitar/shords_data...  major
# ..                                                 ...    ...
# 497  /Users/jay/Jupyter Projects/Guitar/shords_data...  minor
# 498  /Users/jay/Jupyter Projects/Guitar/shords_data...  minor
# 499  /Users/jay/Jupyter Projects/Guitar/shords_data...  minor
# 500  /Users/jay/Jupyter Projects/Guitar/shords_data...  minor
# 501  /Users/jay/Jupyter Projects/Guitar/shords_data...  minor
#
# [502 rows x 2 columns]

# %% [markdown]
# ## Statistical Modeling ##

# %%
print("Shape: ", df.shape)
print("\nCounts:\n", df["Labels"].value_counts())

print()

plt.figure(figsize=(8,8))
plt.pie(df["Labels"].value_counts(), labels = df["Labels"].value_counts().index, autopct="%1.1f%%")
plt.title("Labels Distribution")
plt.show()
# Out:
# Shape:  (502, 2)
#
# Counts:
#  Labels
# minor    252
# major    250
# Name: count, dtype: int64

# %%
for i in range(3):
    x = random.randint(0, len(df))
    
    real_ad, real_sr = librosa.load(df.iloc[x,0])
    plt.figure(figsize=(12, 4))
    plt.plot(real_ad)
    plt.title(f"{df.iloc[x,1]} Audio Data {x}")
    plt.show()
    
    real_spec = np.abs(librosa.stft(real_ad))
    real_spec = librosa.amplitude_to_db(real_spec, ref=np.max)
    
    plt.figure(figsize=(14, 5))
    librosa.display.specshow(real_spec, sr=real_sr, x_axis="time", y_axis="log")
    plt.colorbar(format="%+2.0f dB")
    plt.title(f"{df.iloc[x,1]} Audio Spectogram {x}")
    plt.show()
    
    real_mel_spect = librosa.feature.melspectrogram(y=real_ad, sr=real_sr)
    real_mel_spect = librosa.power_to_db(real_mel_spect, ref=np.max)
    
    plt.figure(figsize=(14, 5))
    librosa.display.specshow(real_mel_spect, y_axis="mel", x_axis="time")
    plt.title(f"{df.iloc[x,1]} Audio Mel Spectogram {x}")
    plt.colorbar(format="%+2.0f dB")
    plt.show()
    
    real_chroma = librosa.feature.chroma_cqt(y=real_ad, sr=real_sr, bins_per_octave=36)
    
    plt.figure(figsize=(14, 5))
    librosa.display.specshow(real_chroma, sr=real_sr, x_axis="time", y_axis="chroma", vmin=0, vmax=1)
    plt.colorbar()
    plt.title(f"{df.iloc[x,1]} Audio Chromagram {x}")
    plt.show()
    
    real_mfccs = librosa.feature.mfcc(y=real_ad, sr=real_sr)
    
    plt.figure(figsize=(14, 5))
    librosa.display.specshow(real_mfccs, sr=real_sr, x_axis="time")
    plt.colorbar()
    plt.title(f"{df.iloc[x,1]} Audio Mel-Frequency Cepstral Coefficients (MFCCs) {x}")
    plt.show()

# %% [markdown]
# ## Training Model ##

# %%
le = LabelEncoder()
df["Labels"] = le.fit_transform(df["Labels"])

train = df.sample(frac = 0.7, random_state = 7)
test = df.drop(train.index)

val = test.sample(frac = 0.5, random_state = 7)
test = test.drop(val.index)

print(train.shape)
print(test.shape)
print(val.shape)
# Out:
# (351, 2)
# (75, 2)
# (76, 2)

# %%
class CustomAudioDataset(Dataset):
    def __init__(self, dataframe):
        self.dataframe = dataframe
        self.labels = torch.Tensor(list(dataframe["Labels"])).type(torch.LongTensor).to(device)
        self.audios = [torch.Tensor(self.get_spectrogram(path)).type(torch.FloatTensor) for path in dataframe["audio_path"]]
        
    def __len__(self):
        return self.dataframe.shape[0]

    def __getitem__(self, idx):
        img_path = self.dataframe.iloc[idx, 0]
        label = torch.Tensor(self.labels[idx]).to(device)
        audio = self.audios[idx].unsqueeze(0).to(device)
        return audio, label

    def get_spectrogram(self, file_path):
        sr = 44000
        duration = 5

        img_height = 128
        img_width = 256

        signal, sr = librosa.load(file_path, sr = sr, duration = duration)
        spec = librosa.feature.melspectrogram(y = signal, sr = sr, n_fft=2048, hop_length = 512, n_mels = 128)
        spec_db = librosa.power_to_db(spec, ref = np.max)

        spec_resized = librosa.util.fix_length(spec_db, size = (duration*sr) // 512+1)
        spec_resized = resize(spec_resized, (img_height, img_width), anti_aliasing=True)
        return spec_resized

# %%
train_dataset = CustomAudioDataset(dataframe = train)
val_dataset = CustomAudioDataset(dataframe = val)
test_dataset = CustomAudioDataset(dataframe = test)

# %%
LR = 1e-4
BATCH_SIZE = 2
EPOCHS = 100

# %%
train_loader = DataLoader(train_dataset, batch_size = BATCH_SIZE, shuffle = True)
val_loader = DataLoader(val_dataset, batch_size = BATCH_SIZE, shuffle = True)
test_loader = DataLoader(test_dataset, batch_size = BATCH_SIZE, shuffle = True)

# %%
class Net(nn.Module):
    def __init__(self):
        super().__init__()

        self.conv1 = nn.Conv2d(1, 16, kernel_size = 3, padding = 1)
        self.conv2 = nn.Conv2d(16, 32, kernel_size = 3, padding = 1)
        self.conv3 = nn.Conv2d(32, 64, kernel_size = 3, padding = 1)
        self.conv4 = nn.Conv2d(64, 128, kernel_size = 3, padding = 1)
        self.conv5 = nn.Conv2d(128, 256, kernel_size = 3, padding = 1)


        self.pooling = nn.MaxPool2d(2, 2)
        self.relu = nn.ReLU()

        self.flatten = nn.Flatten()
        self.linear1 = nn.Linear((256*4*8), 4096)
        self.linear2 = nn.Linear(4096, 1024)
        self.linear3 = nn.Linear(1024, 512)
        self.linear4 = nn.Linear(512, 256)
        self.linear5 = nn.Linear(256, 128)

        self.output = nn.Linear(128, len(df["Labels"].unique()))

        self.dropout = nn.Dropout(0.5)

    def forward(self, x):
        x = self.conv1(x)
        x = self.pooling(x)
        
        x = self.conv2(x)
        x = self.pooling(x)
        
        x = self.conv3(x)
        x = self.pooling(x)

        x = self.conv4(x)
        x = self.pooling(x)

        x = self.conv5(x)
        x = self.pooling(x)
                
        x = self.relu(x)

        x = x.view(x.size(0), -1)

        x = self.flatten(x)
        
        x = self.linear1(x)
        x = self.dropout(x)

        x = self.linear2(x)
        x = self.dropout(x)

        x = self.linear3(x)
        x = self.dropout(x)
        
        x = self.linear4(x)
        x = self.dropout(x)
                
        x = self.linear5(x)
        x = self.dropout(x)
        
        x = self.output(x)
        return x

# %%
model = Net().to(device)
print(model)
# Out:
# Net(
#   (conv1): Conv2d(1, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv2): Conv2d(16, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv3): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv4): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv5): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (pooling): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (relu): ReLU()
#   (flatten): Flatten(start_dim=1, end_dim=-1)
#   (linear1): Linear(in_features=8192, out_features=4096, bias=True)
#   (linear2): Linear(in_features=4096, out_features=1024, bias=True)
#   (linear3): Linear(in_features=1024, out_features=512, bias=True)
#   (linear4): Linear(in_features=512, out_features=256, bias=True)
#   (linear5): Linear(in_features=256, out_features=128, bias=True)
#   (output): Linear(in_features=128, out_features=2, bias=True)
#   (dropout): Dropout(p=0.5, inplace=False)
# )

# %%
summary(model)
# Out:
# =================================================================
# Layer (type:depth-idx)                   Param #
# =================================================================
# Net                                      --
# ├─Conv2d: 1-1                            160
# ├─Conv2d: 1-2                            4,640
# ├─Conv2d: 1-3                            18,496
# ├─Conv2d: 1-4                            73,856
# ├─Conv2d: 1-5                            295,168
# ├─MaxPool2d: 1-6                         --
# ├─ReLU: 1-7                              --
# ├─Flatten: 1-8                           --
# ├─Linear: 1-9                            33,558,528
# ├─Linear: 1-10                           4,195,328
# ├─Linear: 1-11                           524,800
# ├─Linear: 1-12                           131,328
# ├─Linear: 1-13                           32,896
# ├─Linear: 1-14                           258
# ├─Dropout: 1-15                          --
# =================================================================
# Total params: 38,835,458
# Trainable params: 38,835,458
# Non-trainable params: 0
# =================================================================

# %%
criterion = nn.CrossEntropyLoss()
optimizer = Adam(model.parameters(), lr = LR)

# %%
total_loss_train_plot = []
total_loss_validation_plot = []
total_acc_train_plot = []
total_acc_validation_plot = []

start_time = time.time()

for epoch in range(EPOCHS):
    total_acc_train = 0
    total_loss_train = 0
    total_acc_val = 0
    total_loss_val = 0

    for inputs, labels in train_loader:
        outputs = model(inputs)
        train_loss = criterion(outputs, labels)
        total_loss_train += train_loss.item()

        train_loss.backward()
        
        train_acc = (torch.argmax(outputs, axis = 1) == labels).sum().item()
        total_acc_train += train_acc
        
        optimizer.step()
        optimizer.zero_grad()

    with torch.no_grad():
        for inputs, labels in val_loader:
            outputs = model(inputs)
            val_loss = criterion(outputs, labels)
            total_loss_val += val_loss.item()
            
            val_acc = (torch.argmax(outputs, axis = 1) == labels).sum().item()
            total_acc_val += val_acc

    total_loss_train_plot.append(round(total_loss_train/1000, 4))
    total_loss_validation_plot.append(round(total_loss_val/1000, 4))
    
    total_acc_train_plot.append(round(total_acc_train/train_dataset.__len__()*100, 4))
    total_acc_validation_plot.append(round(total_acc_val/val_dataset.__len__()*100, 4))

    print(f'''Epoch no. {epoch+1}/{EPOCHS} 
    Training Loss: {round(total_loss_train/100, 4)} 
    Training Accuracy: {round(total_acc_train/train_dataset.__len__()*100, 4)} 
    Validation Loss: {round(total_loss_val/100, 4)} 
    Validation Accuracy: {round(total_acc_val/val_dataset.__len__()*100, 4)}''')

    print("="*50)

print("Training Time is: ", round((time.time() - start_time), 4), " Seconds")
# Out:
# Epoch no. 1/100
#     Training Loss: 1.3437
#     Training Accuracy: 51.2821
#     Validation Loss: 0.2495
#     Validation Accuracy: 61.8421
# ==================================================
# Epoch no. 2/100
#     Training Loss: 1.1462
#     Training Accuracy: 62.963
#     Validation Loss: 0.2479
#     Validation Accuracy: 60.5263
# ==================================================
# Epoch no. 3/100
#     Training Loss: 1.154
#     Training Accuracy: 62.3932
#     Validation Loss: 0.271
#     Validation Accuracy: 65.7895
# ==================================================
# Epoch no. 4/100
#     Training Loss: 1.1104
#     Training Accuracy: 64.9573
#     Validation Loss: 0.2425
#     Validation Accuracy: 60.5263
# ==================================================
# Epoch no. 5/100
#     Training Loss: 1.1354
#     Training Accuracy: 61.5385
#     Validation Loss: 0.2455
#     Validation Accuracy: 56.5789
# ==================================================
# Epoch no. 6/100
#     Training Loss: 1.1326
#     Training Accuracy: 66.6667
#     Validation Loss: 0.2485
#     Validation Accuracy: 60.5263
# ==================================================
# Epoch no. 7/100
#     Training Loss: 1.0952
#     Training Accuracy: 67.5214
#     Validation Loss: 0.247
#     Validation Accuracy: 60.5263
# ==================================================
# Epoch no. 8/100
#     Training Loss: 1.053
#     Training Accuracy: 67.2365
#     Validation Loss: 0.2398
#     Validation Accuracy: 65.7895
# ==================================================
# Epoch no. 9/100
#     Training Loss: 1.0206
#     Training Accuracy: 71.51
#     Validation Loss: 0.248
#     Validation Accuracy: 59.2105
# ==================================================
# Epoch no. 10/100
#     Training Loss: 0.9495
#     Training Accuracy: 72.0798
#     Validation Loss: 0.2272
#     Validation Accuracy: 64.4737
# ==================================================
# Epoch no. 11/100
#     Training Loss: 0.8324
#     Training Accuracy: 79.2023
#     Validation Loss: 0.3237
#     Validation Accuracy: 65.7895
# ==================================================
# Epoch no. 12/100
#     Training Loss: 0.713
#     Training Accuracy: 83.4758
#     Validation Loss: 0.1869
#     Validation Accuracy: 75.0
# ==================================================
# Epoch no. 13/100
#     Training Loss: 0.4277
#     Training Accuracy: 91.1681
#     Validation Loss: 0.3052
#     Validation Accuracy: 68.4211
# ==================================================
# Epoch no. 14/100
#     Training Loss: 0.4993
#     Training Accuracy: 91.453
#     Validation Loss: 0.2204
#     Validation Accuracy: 65.7895
# ==================================================
# Epoch no. 15/100
#     Training Loss: 0.1739
#     Training Accuracy: 97.4359
#     Validation Loss: 0.3768
#     Validation Accuracy: 68.4211
# ==================================================
# Epoch no. 16/100
#     Training Loss: 0.3319
#     Training Accuracy: 93.7322
#     Validation Loss: 0.3669
#     Validation Accuracy: 67.1053
# ==================================================
# Epoch no. 17/100
#     Training Loss: 0.388
#     Training Accuracy: 91.7379
#     Validation Loss: 0.3326
#     Validation Accuracy: 65.7895
# ==================================================
# Epoch no. 18/100
#     Training Loss: 0.1309
#     Training Accuracy: 97.4359
#     Validation Loss: 0.2699
#     Validation Accuracy: 65.7895
# ==================================================
# Epoch no. 19/100
#     Training Loss: 0.0729
#     Training Accuracy: 98.8604
#     Validation Loss: 0.3955
#     Validation Accuracy: 72.3684
# ==================================================
# Epoch no. 20/100
#     Training Loss: 0.0039
#     Training Accuracy: 100.0
#     Validation Loss: 0.2708
#     Validation Accuracy: 73.6842
# ==================================================
# Epoch no. 21/100
#     Training Loss: 0.0026
#     Training Accuracy: 100.0
#     Validation Loss: 0.3328
#     Validation Accuracy: 75.0
# ==================================================
# Epoch no. 22/100
#     Training Loss: 0.0016
#     Training Accuracy: 100.0
#     Validation Loss: 0.3184
#     Validation Accuracy: 72.3684
# ==================================================
# Epoch no. 23/100
#     Training Loss: 0.0007
#     Training Accuracy: 100.0
#     Validation Loss: 0.313
#     Validation Accuracy: 75.0
# ==================================================
# Epoch no. 24/100
#     Training Loss: 0.0005
#     Training Accuracy: 100.0
#     Validation Loss: 0.3561
#     Validation Accuracy: 75.0
# ==================================================
# Epoch no. 25/100
#     Training Loss: 0.0003
#     Training Accuracy: 100.0
#     Validation Loss: 0.3347
#     Validation Accuracy: 73.6842
# ==================================================
# Epoch no. 26/100
#     Training Loss: 0.0003
#     Training Accuracy: 100.0
#     Validation Loss: 0.3721
#     Validation Accuracy: 73.6842
# ==================================================
# Epoch no. 27/100
#     Training Loss: 0.0003
#     Training Accuracy: 100.0
#     Validation Loss: 0.383
#     Validation Accuracy: 73.6842
# ==================================================
# Epoch no. 28/100
#     Training Loss: 0.0002
#     Training Accuracy: 100.0
#     Validation Loss: 0.3455
#     Validation Accuracy: 77.6316
# ==================================================
# Epoch no. 29/100
#     Training Loss: 0.0003
#     Training Accuracy: 100.0
#     Validation Loss: 0.3749
#     Validation Accuracy: 78.9474
# ==================================================
# Epoch no. 30/100
#     Training Loss: 0.0003
#     Training Accuracy: 100.0
#     Validation Loss: 0.3614
#     Validation Accuracy: 77.6316
# ==================================================
# Epoch no. 31/100
#     Training Loss: 0.0003
#     Training Accuracy: 100.0
#     Validation Loss: 0.4107
#     Validation Accuracy: 76.3158
# ==================================================
# Epoch no. 32/100
#     Training Loss: 0.0001
#     Training Accuracy: 100.0
#     Validation Loss: 0.3713
#     Validation Accuracy: 75.0
# ==================================================
# Epoch no. 33/100
#     Training Loss: 0.0001
#     Training Accuracy: 100.0
#     Validation Loss: 0.372
#     Validation Accuracy: 75.0
# ==================================================
# Epoch no. 34/100
#     Training Loss: 0.0001
#     Training Accuracy: 100.0
#     Validation Loss: 0.3688
#     Validation Accuracy: 78.9474
# ==================================================
# Epoch no. 35/100
#     Training Loss: 0.0001
#     Training Accuracy: 100.0
#     Validation Loss: 0.4127
#     Validation Accuracy: 77.6316
# ==================================================
# Epoch no. 36/100
#     Training Loss: 0.0001
#     Training Accuracy: 100.0
#     Validation Loss: 0.418
#     Validation Accuracy: 73.6842
# ==================================================
# Epoch no. 37/100
#     Training Loss: 0.0
#     Training Accuracy: 100.0
#     Validation Loss: 0.4313
#     Validation Accuracy: 76.3158
# ==================================================
# Epoch no. 38/100
#     Training Loss: 0.0001
#     Training Accuracy: 100.0
#     Validation Loss: 0.4482
#     Validation Accuracy: 72.3684
# ==================================================
# Epoch no. 39/100
#     Training Loss: 0.0001
#     Training Accuracy: 100.0
#     Validation Loss: 0.4114
#     Validation Accuracy: 77.6316
# ==================================================
# Epoch no. 40/100
#     Training Loss: 0.0
#     Training Accuracy: 100.0
#     Validation Loss: 0.4804
#     Validation Accuracy: 77.6316
# ==================================================
# Epoch no. 41/100
#     Training Loss: 0.0001
#     Training Accuracy: 100.0
#     Validation Loss: 0.4431
#     Validation Accuracy: 77.6316
# ==================================================
# Epoch no. 42/100
#     Training Loss: 0.0002
#     Training Accuracy: 100.0
#     Validation Loss: 0.4507
#     Validation Accuracy: 76.3158
# ==================================================
# Epoch no. 43/100
#     Training Loss: 0.0001
#     Training Accuracy: 100.0
#     Validation Loss: 0.4474
#     Validation Accuracy: 75.0
# ==================================================
# Epoch no. 44/100
#     Training Loss: 0.0
#     Training Accuracy: 100.0
#     Validation Loss: 0.5216
#     Validation Accuracy: 76.3158
# ==================================================
# Epoch no. 45/100
#     Training Loss: 0.0
#     Training Accuracy: 100.0
#     Validation Loss: 0.4345
#     Validation Accuracy: 75.0
# ==================================================
# Epoch no. 46/100
#     Training Loss: 0.0
#     Training Accuracy: 100.0
#     Validation Loss: 0.4614
#     Validation Accuracy: 76.3158
# ==================================================
# Epoch no. 47/100
#     Training Loss: 0.0001
#     Training Accuracy: 100.0
#     Validation Loss: 0.4699
#     Validation Accuracy: 77.6316
# ==================================================
# Epoch no. 48/100
#     Training Loss: 0.0
#     Training Accuracy: 100.0
#     Validation Loss: 0.4936
#     Validation Accuracy: 75.0
# ==================================================
# Epoch no. 49/100
#     Training Loss: 0.0
#     Training Accuracy: 100.0
#     Validation Loss: 0.611
#     Validation Accuracy: 75.0
# ==================================================
# Epoch no. 50/100
#     Training Loss: 0.0
#     Training Accuracy: 100.0
#     Validation Loss: 0.5112
#     Validation Accuracy: 78.9474
# ==================================================
# Epoch no. 51/100
#     Training Loss: 0.0
#     Training Accuracy: 100.0
#     Validation Loss: 0.5313
#     Validation Accuracy: 77.6316
# ==================================================
# Epoch no. 52/100
#     Training Loss: 0.0
#     Training Accuracy: 100.0
#     Validation Loss: 0.4591
#     Validation Accuracy: 75.0
# ==================================================
# Epoch no. 53/100
#     Training Loss: 0.0
#     Training Accuracy: 100.0
#     Validation Loss: 0.5734
#     Validation Accuracy: 76.3158
# ==================================================
# Epoch no. 54/100
#     Training Loss: 0.0
#     Training Accuracy: 100.0
#     Validation Loss: 0.4607
#     Validation Accuracy: 73.6842
# ==================================================
# Epoch no. 55/100
#     Training Loss: 0.0
#     Training Accuracy: 100.0
#     Validation Loss: 0.5635
#     Validation Accuracy: 75.0
# ==================================================
# Epoch no. 56/100
#     Training Loss: 0.0
#     Training Accuracy: 100.0
#     Validation Loss: 0.5778
#     Validation Accuracy: 72.3684
# ==================================================
# Epoch no. 57/100
#     Training Loss: 0.0
#     Training Accuracy: 100.0
#     Validation Loss: 0.4821
#     Validation Accuracy: 77.6316
# ==================================================
# Epoch no. 58/100
#     Training Loss: 0.0
#     Training Accuracy: 100.0
#     Validation Loss: 0.5969
#     Validation Accuracy: 75.0
# ==================================================
# Epoch no. 59/100
#     Training Loss: 0.0
#     Training Accuracy: 100.0
#     Validation Loss: 0.5507
#     Validation Accuracy: 75.0
# ==================================================
# Epoch no. 60/100
#     Training Loss: 0.0
#     Training Accuracy: 100.0
#     Validation Loss: 0.5311
#     Validation Accuracy: 75.0
# ==================================================
# Epoch no. 61/100
#     Training Loss: 0.0
#     Training Accuracy: 100.0
#     Validation Loss: 0.5092
#     Validation Accuracy: 77.6316
# ==================================================
# Epoch no. 62/100
#     Training Loss: 0.0
#     Training Accuracy: 100.0
#     Validation Loss: 0.5218
#     Validation Accuracy: 78.9474
# ==================================================
# Epoch no. 63/100
#     Training Loss: 0.0
#     Training Accuracy: 100.0
#     Validation Loss: 0.5217
#     Validation Accuracy: 77.6316
# ==================================================
# Epoch no. 64/100
#     Training Loss: 0.0
#     Training Accuracy: 100.0
#     Validation Loss: 0.4745
#     Validation Accuracy: 75.0
# ==================================================
# Epoch no. 65/100
#     Training Loss: 0.0
#     Training Accuracy: 100.0
#     Validation Loss: 0.4907
#     Validation Accuracy: 77.6316
# ==================================================
# Epoch no. 66/100
#     Training Loss: 0.0
#     Training Accuracy: 100.0
#     Validation Loss: 0.4937
#     Validation Accuracy: 75.0
# ==================================================
# Epoch no. 67/100
#     Training Loss: 0.0
#     Training Accuracy: 100.0
#     Validation Loss: 0.5253
#     Validation Accuracy: 73.6842
# ==================================================
# Epoch no. 68/100
#     Training Loss: 0.0
#     Training Accuracy: 100.0
#     Validation Loss: 0.55
#     Validation Accuracy: 76.3158
# ==================================================
# Epoch no. 69/100
#     Training Loss: 0.0
#     Training Accuracy: 100.0
#     Validation Loss: 0.5868
#     Validation Accuracy: 73.6842
# ==================================================
# Epoch no. 70/100
#     Training Loss: 0.0
#     Training Accuracy: 100.0
#     Validation Loss: 0.5672
#     Validation Accuracy: 73.6842
# ==================================================
# Epoch no. 71/100
#     Training Loss: 0.0
#     Training Accuracy: 100.0
#     Validation Loss: 0.5477
#     Validation Accuracy: 76.3158
# ==================================================
# Epoch no. 72/100
#     Training Loss: 0.0
#     Training Accuracy: 100.0
#     Validation Loss: 0.6249
#     Validation Accuracy: 76.3158
# ==================================================
# Epoch no. 73/100
#     Training Loss: 0.0
#     Training Accuracy: 100.0
#     Validation Loss: 0.6091
#     Validation Accuracy: 75.0
# ==================================================
# Epoch no. 74/100
#     Training Loss: 0.0
#     Training Accuracy: 100.0
#     Validation Loss: 0.6085
#     Validation Accuracy: 75.0
# ==================================================
# Epoch no. 75/100
#     Training Loss: 0.0
#     Training Accuracy: 100.0
#     Validation Loss: 0.5791
#     Validation Accuracy: 77.6316
# ==================================================
# Epoch no. 76/100
#     Training Loss: 0.0
#     Training Accuracy: 100.0
#     Validation Loss: 0.5904
#     Validation Accuracy: 72.3684
# ==================================================
# Epoch no. 77/100
#     Training Loss: 0.0
#     Training Accuracy: 100.0
#     Validation Loss: 0.7359
#     Validation Accuracy: 73.6842
# ==================================================
# Epoch no. 78/100
#     Training Loss: 0.0
#     Training Accuracy: 100.0
#     Validation Loss: 0.5985
#     Validation Accuracy: 76.3158
# ==================================================
# Epoch no. 79/100
#     Training Loss: 0.0
#     Training Accuracy: 100.0
#     Validation Loss: 0.6273
#     Validation Accuracy: 76.3158
# ==================================================
# Epoch no. 80/100
#     Training Loss: 0.0
#     Training Accuracy: 100.0
#     Validation Loss: 0.7272
#     Validation Accuracy: 76.3158
# ==================================================
# Epoch no. 81/100
#     Training Loss: 0.0
#     Training Accuracy: 100.0
#     Validation Loss: 0.6982
#     Validation Accuracy: 76.3158
# ==================================================
# Epoch no. 82/100
#     Training Loss: 0.0
#     Training Accuracy: 100.0
#     Validation Loss: 0.7511
#     Validation Accuracy: 75.0
# ==================================================
# Epoch no. 83/100
#     Training Loss: 0.0
#     Training Accuracy: 100.0
#     Validation Loss: 0.6557
#     Validation Accuracy: 78.9474
# ==================================================
# Epoch no. 84/100
#     Training Loss: 0.0
#     Training Accuracy: 100.0
#     Validation Loss: 0.6038
#     Validation Accuracy: 73.6842
# ==================================================
# Epoch no. 85/100
#     Training Loss: 0.0
#     Training Accuracy: 100.0
#     Validation Loss: 0.7065
#     Validation Accuracy: 73.6842
# ==================================================
# Epoch no. 86/100
#     Training Loss: 0.0
#     Training Accuracy: 100.0
#     Validation Loss: 0.724
#     Validation Accuracy: 76.3158
# ==================================================
# Epoch no. 87/100
#     Training Loss: 0.0
#     Training Accuracy: 100.0
#     Validation Loss: 0.6176
#     Validation Accuracy: 76.3158
# ==================================================
# Epoch no. 88/100
#     Training Loss: 0.0
#     Training Accuracy: 100.0
#     Validation Loss: 0.5852
#     Validation Accuracy: 76.3158
# ==================================================
# Epoch no. 89/100
#     Training Loss: 0.0
#     Training Accuracy: 100.0
#     Validation Loss: 0.7001
#     Validation Accuracy: 73.6842
# ==================================================
# Epoch no. 90/100
#     Training Loss: 0.0
#     Training Accuracy: 100.0
#     Validation Loss: 0.7483
#     Validation Accuracy: 76.3158
# ==================================================
# Epoch no. 91/100
#     Training Loss: 0.0
#     Training Accuracy: 100.0
#     Validation Loss: 0.8023
#     Validation Accuracy: 73.6842
# ==================================================
# Epoch no. 92/100
#     Training Loss: 0.0
#     Training Accuracy: 100.0
#     Validation Loss: 0.7133
#     Validation Accuracy: 75.0
# ==================================================
# Epoch no. 93/100
#     Training Loss: 0.0
#     Training Accuracy: 100.0
#     Validation Loss: 0.7334
#     Validation Accuracy: 76.3158
# ==================================================
# Epoch no. 94/100
#     Training Loss: 0.0
#     Training Accuracy: 100.0
#     Validation Loss: 0.678
#     Validation Accuracy: 75.0
# ==================================================
# Epoch no. 95/100
#     Training Loss: 0.0
#     Training Accuracy: 100.0
#     Validation Loss: 0.7418
#     Validation Accuracy: 71.0526
# ==================================================
# Epoch no. 96/100
#     Training Loss: 0.0
#     Training Accuracy: 100.0
#     Validation Loss: 0.7296
#     Validation Accuracy: 73.6842
# ==================================================
# Epoch no. 97/100
#     Training Loss: 0.0
#     Training Accuracy: 100.0
#     Validation Loss: 0.7024
#     Validation Accuracy: 76.3158
# ==================================================
# Epoch no. 98/100
#     Training Loss: 0.0
#     Training Accuracy: 100.0
#     Validation Loss: 0.744
#     Validation Accuracy: 76.3158
# ==================================================
# Epoch no. 99/100
#     Training Loss: 0.0
#     Training Accuracy: 100.0
#     Validation Loss: 0.7467
#     Validation Accuracy: 77.6316
# ==================================================
# Epoch no. 100/100
#     Training Loss: 0.0
#     Training Accuracy: 100.0
#     Validation Loss: 0.6866
#     Validation Accuracy: 75.0
# ==================================================
# Training Time is:  538.4442  Seconds

# %%
with torch.no_grad():
    total_loss_test = 0
    total_acc_test = 0
    for inputs, labels in test_loader:
        predictions = model(inputs)
        
        acc = (torch.argmax(predictions, axis = 1) == labels).sum().item()
        total_acc_test += acc

print(f'''Accuracy Score: {round((total_acc_test/test_dataset.__len__())*100, 4)} 
Loss: {round(total_loss_test/1000, 4)}''')
# Out:
# Accuracy Score: 74.6667
# Loss: 0.0

# %% [markdown]
# ## Post-Training Analysis ##

# %%
fig, axs = plt.subplots(nrows = 1, ncols = 2, figsize = (15,5))

axs[0].plot(total_loss_train_plot, label = "Training Loss")
axs[0].plot(total_loss_validation_plot, label = "Validation Loss")
axs[0].set_title("Training and Validation loss over Epochs")
axs[0].set_xlabel("Epochs")
axs[0].set_ylabel("Loss")
axs[0].set_ylim([0,1])
axs[0].legend()

axs[1].plot(total_acc_train_plot, label = "Training Loss")
axs[1].plot(total_acc_validation_plot, label = "Validation Loss")
axs[1].set_title("Training and Validation loss over Epochs")
axs[1].set_xlabel("Epochs")
axs[1].set_ylabel("Accuracy")
axs[1].set_ylim([0,101])
axs[1].legend()

plt.show()

# %%
torch.save(model.state_dict(), "Guitar.pth")

# %%
loaded_model = Net().to(device)
loaded_model.load_state_dict(torch.load("Guitar.pth"))
loaded_model.eval()
# Out:
# Net(
#   (conv1): Conv2d(1, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv2): Conv2d(16, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv3): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv4): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv5): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (pooling): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (relu): ReLU()
#   (flatten): Flatten(start_dim=1, end_dim=-1)
#   (linear1): Linear(in_features=8192, out_features=4096, bias=True)
#   (linear2): Linear(in_features=4096, out_features=1024, bias=True)
#   (linear3): Linear(in_features=1024, out_features=512, bias=True)
#   (linear4): Linear(in_features=512, out_features=256, bias=True)
#   (linear5): Linear(in_features=256, out_features=128, bias=True)
#   (output): Linear(in_features=128, out_features=2, bias=True)
#   (dropout): Dropout(p=0.5, inplace=False)
# )

# %%
y_pred = []
y_true = []

loaded_model.eval()

with torch.no_grad():
    for inputs, labels in test_loader:
        inputs = inputs.to(device)
        labels = labels.to(device)

        outputs = model(inputs)
        predictions = torch.max(outputs, 1)[1]

        y_pred.extend(predictions.cpu().numpy())
        y_true.extend(labels.cpu().numpy())

classes = le.inverse_transform(df["Labels"].unique().tolist())

cf_matrix = confusion_matrix(y_true, y_pred, labels=list(range(len(classes))))
df_cm = pd.DataFrame(cf_matrix, index=classes, columns=classes)

plt.figure(figsize=(12, 7))
sn.heatmap(df_cm, annot=True)
plt.title("Confusion Matrix\n", fontsize=15)
plt.xlabel("\nPredicted", fontsize=12)
plt.ylabel("True\n", fontsize=12)
plt.xticks(rotation=45)
plt.yticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
def get_spectrogram_for_display(file_path):
    sr = 44000
    duration = 5
    img_height = 128
    img_width = 256

    signal, sr = librosa.load(file_path, sr=sr, duration=duration)
    spec = librosa.feature.melspectrogram(y=signal, sr=sr, n_fft=2048, hop_length=512, n_mels=img_height)
    spec_db = librosa.power_to_db(spec, ref=np.max)
    spec_resized = librosa.util.fix_length(spec_db, size=(duration * sr) // 512 + 1)
    spec_resized = resize(spec_resized, (img_height, img_width), anti_aliasing=True)
    
    return spec_resized

# %%
def predict_audio(file_path, return_probs=False):
    loaded_model.eval()
    
    spec = get_spectrogram_for_display(file_path)
    audio_tensor = torch.tensor(spec, dtype=torch.float32).unsqueeze(0).unsqueeze(0).to(device)
    
    with torch.no_grad():
        output = loaded_model(audio_tensor)
        probs = torch.nn.functional.softmax(output, dim=1)
        predicted_class = torch.argmax(probs, dim=1).item()
    
    if return_probs:
        return probs.squeeze().cpu().numpy()
    
    return le.inverse_transform([predicted_class])[0]

# %%
def prediction(x, paths, label_names=None):
    fig, axes = plt.subplots(1, x, figsize=(10*x, 8))

    if x == 1:
        axes = [axes]

    for i in range(x):
        path = paths[i]
        spec = get_spectrogram_for_display(path)
        
        pred_class = predict_audio(path)
        probs = predict_audio(path, return_probs=True)
    
        pred_index = le.transform([pred_class])[0]
    
        ax = axes[i]
        img = librosa.display.specshow(
            spec, sr=44000, hop_length=512,
            x_axis="time", y_axis="mel", ax=ax, cmap="magma"
        )
        
        title_text = f"Predicted Class: {pred_class}\n"
        title_text += f"Class Probability: {probs[pred_index]:.2f}"
        
        ax.set_title(title_text, fontsize=14)
        ax.axis("off")

# %%
paths = [
    f"{dir_path}/A major.wav",
    f"{dir_path}/C major.wav",
    f"{dir_path}/E minor.wav"
]

label_names = df["Labels"].unique().tolist()

prediction(len(paths), paths, label_names=label_names)

# %%
probs = F.sigmoid(outputs)
plt.hist(np.array(probs.cpu()))
plt.show()
